# %%
# import libraries and load data
import sys

import pandas as pd
import numpy as np
import sklearn as skl
import tensorflow as tf
import scikeras as sck
from tqdm import tqdm

from sklearn.model_selection import PredefinedSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.regularizers import l1, l2, l1_l2
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping
from collections import defaultdict

#Import the data
return_data = pd.read_pickle('returns_chars_panel.pkl')
return_data['date'] = pd.to_datetime(return_data['date'])
print(return_data)

macro_data = pd.read_pickle('macro_timeseries.pkl')
macro_data['date'] = pd.to_datetime(macro_data['date'])
print(macro_data)

original_data = pd.merge(return_data, macro_data, how='inner', on='date')
print(original_data)
# Out:
#               date  permno  excess_ret       ret     rfree     mvel1  \
# 0       1986-02-01   10000   -0.262610 -0.257143  0.005467 -0.375440
# 1       1986-03-01   10000    0.360335  0.365385  0.005050 -0.496811
# 2       1986-04-01   10000   -0.103717 -0.098592  0.005125 -0.401783
# 3       1986-05-01   10000   -0.227831 -0.222656  0.005175 -0.435735
# 4       1986-06-01   10000   -0.009883 -0.005025  0.004858 -0.534203
# ...            ...     ...         ...       ...       ...       ...
# 3739444 2016-08-01   93436   -0.097265 -0.097023  0.000242  0.948225
# 3739445 2016-09-01   93436   -0.037915 -0.037640  0.000275  0.940011
# 3739446 2016-10-01   93436   -0.031253 -0.030878  0.000375  0.936380
# 3739447 2016-11-01   93436   -0.042553 -0.042128  0.000425  0.936096
# 3739448 2016-12-01   93436    0.127822  0.128247  0.000425  0.929911
#
#              beta    betasq     chmom    dolvol  ...    stdacc     stdcf  \
# 0        0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 1        0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2        0.000000  0.000000  0.000000 -0.521182  ...  0.000000  0.000000
# 3        0.000000  0.000000  0.000000 -0.439391  ...  0.000000  0.000000
# 4        0.000000  0.000000  0.000000 -0.499678  ...  0.000000  0.000000
# ...           ...       ...       ...       ...  ...       ...       ...
# 3739444  0.629726  0.627131  0.490549  0.993659  ...  0.671316  0.825632
# 3739445  0.654357  0.651773  0.268347  0.993663  ...  0.527009  0.698287
# 3739446  0.650269  0.647670 -0.310701  0.993629  ...  0.516098  0.690407
# 3739447  0.638693  0.636094 -0.806963  0.993638  ...  0.430076  0.661731
# 3739448  0.622969  0.620384 -0.540670  0.993655  ...  0.416828  0.658252
#
#                ms  baspread       ill    maxret    retvol  std_dolvol  \
# 0        0.000000  0.572822  0.361538  0.938929  0.873640    0.399871
# 1        0.000000  0.417504  0.520205 -0.138898  0.328870    0.078782
# 2        0.000000  0.091488  0.329401  0.813365  0.660035    0.142035
# 3        0.000000  0.329949  0.438295 -0.683852 -0.759048    0.388029
# 4        0.000000  0.510140  0.610586  0.724257  0.608819   -0.128302
# ...           ...       ...       ...       ...       ...         ...
# 3739444 -0.078854  0.148155 -0.981099  0.045653  0.025560   -0.875022
# 3739445  0.046292 -0.098019 -0.980351 -0.351920 -0.320000   -0.689770
# 3739446  0.057409  0.146723 -0.976785 -0.233878  0.146123   -0.695017
# 3739447  0.056117  0.155493 -0.974719  0.488592  0.270109   -0.117120
# 3739448  0.061157  0.116165 -0.979703 -0.327502 -0.035871   -0.964642
#
#          std_turn  zerotrade
# 0        0.120000  -0.177810
# 1       -0.411202   0.130393
# 2       -0.131985   0.119017
# 3       -0.199555   0.135402
# 4       -0.025964   0.007879
# ...           ...        ...
# 3739444  0.645082  -0.902396
# 3739445  0.550254  -0.826056
# 3739446  0.727944  -0.869879
# 3739447  0.863086  -0.934702
# 3739448  0.688244  -0.916010
#
# [3739449 rows x 99 columns]
#            date        dp        ep       b/m  crsp_spvw      svar     tbl  \
# 671  1926-12-01       NaN       NaN       NaN        NaN       NaN     NaN
# 672  1927-01-01 -2.973012 -2.386837  0.441476   0.026047  0.000465  0.0307
# 673  1927-02-01 -2.942374 -2.374773  0.443706  -0.002910  0.000470  0.0323
# 674  1927-03-01 -2.979535 -2.430353  0.428501   0.045522  0.000287  0.0329
# 675  1927-04-01 -2.976535 -2.445079  0.469765   0.007324  0.000924  0.0320
# ...         ...       ...       ...       ...        ...       ...     ...
# 1785 2019-10-01 -3.951689 -3.108987  0.233377   0.018791  0.000605  0.0189
# 1786 2019-11-01 -3.965984 -3.112869  0.232261   0.021621  0.001510  0.0165
# 1787 2019-12-01 -3.993568 -3.130267  0.223938   0.036206  0.000306  0.0154
# 1788 2020-01-01 -4.015896 -3.142629  0.220116   0.029787  0.000502  0.0154
# 1789 2020-02-01 -4.006626 -3.197893  0.222316   0.000108  0.001119  0.0152
#
#          tms     dfy     dfr      ntis      infl
# 671      NaN     NaN     NaN       NaN       NaN
# 672   0.0047  0.0100 -0.0022  0.050876  0.000000
# 673   0.0028  0.0095 -0.0019  0.050824 -0.011299
# 674   0.0018  0.0092 -0.0019  0.051668 -0.005714
# 675   0.0011  0.0092 -0.0170  0.046357 -0.005747
# ...      ...     ...     ...       ...       ...
# 1785 -0.0019  0.0088  0.0002 -0.010862  0.000783
# 1786  0.0006  0.0091  0.0058 -0.013181  0.002286
# 1787  0.0027  0.0088  0.0073 -0.007820 -0.000536
# 1788  0.0032  0.0087  0.0164 -0.007222 -0.000910
# 1789  0.0024  0.0083 -0.0113 -0.007717  0.003880
#
# [1119 rows x 12 columns]
#               date  permno  excess_ret       ret     rfree     mvel1  beta  \
# 0       1986-02-01   10000   -0.262610 -0.257143  0.005467 -0.375440   0.0
# 1       1986-02-01   10001    0.014941  0.020408  0.005467 -0.700991   0.0
# 2       1986-02-01   10002    0.134318  0.139785  0.005467 -0.438120   0.0
# 3       1986-02-01   10003    0.005897  0.011364  0.005467  0.008634   0.0
# 4       1986-02-01   10005   -0.338800 -0.333333  0.005467 -0.919092   0.0
# ...            ...     ...         ...       ...       ...       ...   ...
# 3739444 1986-01-01   93252   -0.025491 -0.019608  0.005883 -0.415444   0.0
# 3739445 1986-01-01   93279    0.122322  0.128205  0.005883 -0.301213   0.0
# 3739446 1986-01-01   93287    0.290413  0.296296  0.005883 -0.177090   0.0
# 3739447 1986-01-01   93308    0.005882  0.011765  0.005883 -0.089981   0.0
# 3739448 1986-01-01   93316    0.061685  0.067568  0.005883 -0.190651   0.0
#
#          betasq  chmom    dolvol  ...      ep_y       b/m  crsp_spvw     svar  \
# 0           0.0    0.0  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 1           0.0    0.0  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 2           0.0    0.0  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 3           0.0    0.0  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 4           0.0    0.0  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# ...         ...    ...       ...  ...       ...       ...        ...      ...
# 3739444     0.0    0.0 -0.660377  ... -2.671478  0.592693   0.048156  0.00123
# 3739445     0.0    0.0 -0.628497  ... -2.671478  0.592693   0.048156  0.00123
# 3739446     0.0    0.0 -0.104099  ... -2.671478  0.592693   0.048156  0.00123
# 3739447     0.0    0.0 -0.546519  ... -2.671478  0.592693   0.048156  0.00123
# 3739448     0.0    0.0 -0.063110  ... -2.671478  0.592693   0.048156  0.00123
#
#             tbl     tms     dfy     dfr      ntis      infl
# 0        0.0707  0.0251  0.0139  0.0070 -0.019172  0.002745
# 1        0.0707  0.0251  0.0139  0.0070 -0.019172  0.002745
# 2        0.0707  0.0251  0.0139  0.0070 -0.019172  0.002745
# 3        0.0707  0.0251  0.0139  0.0070 -0.019172  0.002745
# 4        0.0707  0.0251  0.0139  0.0070 -0.019172  0.002745
# ...         ...     ...     ...     ...       ...       ...
# 3739444  0.0710  0.0246  0.0142 -0.0072 -0.019465  0.002752
# 3739445  0.0710  0.0246  0.0142 -0.0072 -0.019465  0.002752
# 3739446  0.0710  0.0246  0.0142 -0.0072 -0.019465  0.002752
# 3739447  0.0710  0.0246  0.0142 -0.0072 -0.019465  0.002752
# 3739448  0.0710  0.0246  0.0142 -0.0072 -0.019465  0.002752
#
# [3739449 rows x 110 columns]

# %% [markdown]
# **Preparation for Grid Search**

# %%
#Split a small portion of data for experiments
exp_size = 0.00001
n_exp = int(original_data.shape[0] * exp_size)
exp_data = original_data.iloc[:n_exp, ] 
X_exp = exp_data.drop(['ret','excess_ret','rfree','permno','date'], axis=1)
y_exp = exp_data['excess_ret']
print(X_exp)
print(y_exp)
X = X_exp.values
y = y_exp.values
# Out:
#        mvel1      beta    betasq     chmom    dolvol   idiovol    indmom  \
# 0  -0.375440  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 1  -0.700991  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 2  -0.438120  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 3   0.008634  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 4  -0.919092  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 5   0.158299  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 6   0.020147  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 7  -0.705469  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 8  -0.376719  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 9  -0.527023  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 10 -0.793412  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 11 -0.003838  0.743782  0.743782  0.382145  0.338629  0.384147 -0.776019
# 12  0.513911  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 13  0.604093  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 14 -0.564439  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 15  0.216821  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 16  0.445475  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 17 -0.526063  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 18 -0.099137  0.000000  0.000000  0.000000  0.000000  0.000000  0.305196
# 19 -0.464023  0.124351  0.121131 -0.885674 -0.572054 -0.184827 -0.710152
# 20  0.279821  0.501521  0.500805  0.052576  0.361647 -0.028091 -0.848601
# 21  0.699392 -0.586330 -0.606012 -0.083627  0.221916 -0.986044  0.053397
# 22 -0.751839 -0.805690 -0.842548 -0.788285 -0.776139  0.724817 -0.615827
# 23 -0.497282 -0.332618 -0.341564 -0.401200 -0.471551  0.414206 -0.476259
# 24 -0.663575  0.412775  0.410986  0.831687 -0.481277  0.901235  0.872582
# 25 -0.778062 -0.815709 -0.853283 -0.769936 -0.942941  0.441403 -0.693525
# 26  0.908858 -0.801753 -0.838254  0.368384  0.893986 -0.958132  0.775540
# 27  0.991046 -0.009841 -0.013777 -0.273818  0.990922 -0.802827 -0.723901
# 28 -0.316597 -0.501163 -0.515477  0.850741 -0.237478  0.249955 -0.615827
# 29  0.171730  0.447486  0.446055  0.534933  0.366834  0.376991 -0.960032
# 30  0.126319  0.313294  0.311505 -0.286168  0.334090 -0.085346 -0.289528
# 31  0.844260  0.457148  0.455717 -0.046930  0.887178 -0.382716 -0.693525
# 32 -0.395267 -0.898372 -0.960279  0.718419 -0.546766 -0.978887 -0.403517
# 33 -0.602175  0.915906  0.915906  0.832040 -0.041984  0.730184 -0.289528
# 34  0.963224 -0.440687 -0.453212  0.231122  0.945534 -0.939882  0.837890
# 35  0.910138  0.242441  0.240293  0.030346  0.941644 -0.807479  0.671143
# 36 -0.474896  0.093219  0.089640 -0.527170 -0.443022  0.296475 -0.403517
#
#        mom1m     mom6m    mom12m  ...      ep_y       b/m  crsp_spvw     svar  \
# 0   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 1   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 2   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 3   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 4   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 5   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 6   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 7   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 8   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 9   0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 10  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 11 -0.180766  0.899732  0.914255  ... -2.675897  0.583517   0.004706  0.00192
# 12  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 13  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 14  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 15  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 16  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 17  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 18  0.000000  0.000000  0.000000  ... -2.675897  0.583517   0.004706  0.00192
# 19 -0.034416 -0.401408  0.609386  ... -2.675897  0.583517   0.004706  0.00192
# 20  0.507559 -0.620389 -0.664432  ... -2.675897  0.583517   0.004706  0.00192
# 21 -0.269218  0.160630  0.208539  ... -2.675897  0.583517   0.004706  0.00192
# 22  0.990994 -0.937961 -0.734298  ... -2.675897  0.583517   0.004706  0.00192
# 23  0.010936  0.697854  0.872265  ... -2.675897  0.583517   0.004706  0.00192
# 24  0.682374  0.732730  0.399788  ... -2.675897  0.583517   0.004706  0.00192
# 25 -0.445320  0.119048  0.735356  ... -2.675897  0.583517   0.004706  0.00192
# 26  0.273400  0.383300  0.282992  ... -2.675897  0.583517   0.004706  0.00192
# 27 -0.088453  0.109658  0.303105  ... -2.675897  0.583517   0.004706  0.00192
# 28 -0.700225  0.808853 -0.241002  ... -2.675897  0.583517   0.004706  0.00192
# 29  0.299936 -0.579812 -0.813338  ... -2.675897  0.583517   0.004706  0.00192
# 30 -0.668865 -0.454058 -0.502470  ... -2.675897  0.583517   0.004706  0.00192
# 31 -0.180766 -0.542589 -0.617149  ... -2.675897  0.583517   0.004706  0.00192
# 32  0.670794  0.560027  0.293578  ... -2.675897  0.583517   0.004706  0.00192
# 33  0.749920 -0.552649 -0.894495  ... -2.675897  0.583517   0.004706  0.00192
# 34  0.147636  0.097586 -0.021877  ... -2.675897  0.583517   0.004706  0.00192
# 35  0.551785  0.072770  0.261821  ... -2.675897  0.583517   0.004706  0.00192
# 36  0.959151 -0.747150 -0.279817  ... -2.675897  0.583517   0.004706  0.00192
#
#        tbl     tms     dfy    dfr      ntis      infl
# 0   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 1   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 2   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 3   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 4   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 5   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 6   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 7   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 8   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 9   0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 10  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 11  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 12  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 13  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 14  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 15  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 16  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 17  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 18  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 19  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 20  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 21  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 22  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 23  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 24  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 25  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 26  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 27  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 28  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 29  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 30  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 31  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 32  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 33  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 34  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 35  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
# 36  0.0707  0.0251  0.0139  0.007 -0.019172  0.002745
#
# [37 rows x 105 columns]
# 0    -0.262610
# 1     0.014941
# 2     0.134318
# 3     0.005897
# 4    -0.338800
# 5    -0.202835
# 6     0.114191
# 7     0.192450
# 8    -0.142967
# 9     0.096574
# 10   -0.246846
# 11    0.080953
# 12    0.389078
# 13    0.059622
# 14   -0.137820
# 15    0.108047
# 16    0.356071
# 17    0.067704
# 18    0.242152
# 19   -0.031783
# 20   -0.106384
# 21    0.036787
# 22    0.437156
# 23    0.202080
# 24    0.350089
# 25   -0.039950
# 26    0.083819
# 27    0.094533
# 28    0.082445
# 29   -0.176896
# 30    0.095450
# 31   -0.032990
# 32    0.183977
# 33    0.188081
# 34    0.129969
# 35    0.163413
# 36   -0.021092
# Name: excess_ret, dtype: float64

# %%
#Split the data manually (keep the data sequence in time-series)
train_size = 0.8
test_size = 1 - train_size

n_observations = X.shape[0]
n_train = int(n_observations * train_size)
X_train, X_test = X[:n_train, ], X[n_train:, ]
y_train, y_test = y[:n_train, ], y[n_train:, ]

# %%
#Standardise the data
standard_scaler = skl.preprocessing.StandardScaler()
standard_scaler.fit(X_train)
X_train = standard_scaler.transform(X_train)
X_test = standard_scaler.transform(X_test)

# %% [markdown]
# ```<br><font color='black'>
# Define a hyperparameter space for neural networks with 3 hidden layers```
# ```complex_param_grid_nn_3 = {
#                  'model__optimizer': ['adam', 'sgd', 'rmsprop', 'adagrad'],
#                  'model__learning_rate': [0.1, 0.01, 0.001],
#                  'model__activation_func': ['relu', 'tanh', 'sigmoid', 'elu'],
#                  #'batch_size': [32, 64, 128, 256], #Don't know how to grid search this
#                  #'epochs': [10, 20, 50], #Don't know how to grid search this
#                  'model__neurons_n': [[64, 32, 16], [128, 64, 32], [256, 128, 64]],
#                  'model__dropout_rate': [0.0, 0.2, 0.5],
#                  'model__regularize_terms': [None,
#                                     l1(0.1), l1(0.01), l1(0.001),
#                                     l2(0.1), l2(0.01), l2(0.001),
#                                     l1_l2(l1=0.1, l2=0.1), l1_l2(l1=0.01, l2=0.01),
#                                     l1_l2(l1=0.001, l2=0.001)]
#                  #'loss_func': ['mse', 'mae', 'mape', 'msle', tf.keras.losses.Huber()], #Should be the same as the 'scoring' input of GridSearchCV
#                  #'metrics_func': [['mae'], ['mse'], ['mape'], ['msle'], [rmse_metric]] #Meaningless hyperparameter: Do not influence model performance
#                  #'callbacks': [[early_stopping]] #Dangerous
#                  }```

# %%
#Index-generating function for rolling-window time-series cross validation
each_window_size = int(0.2 * X_train.shape[0])
n_train_window = int(0.75 * each_window_size)
n_test_window = each_window_size - n_train_window

# %%
def rolling_window_index_generator(X_train, train_window_size=n_train_window, test_window_size=n_test_window, step_size=1):
    n_samples = X_train.shape[0]
    indices = np.arange(n_samples)
    for start in range(0, n_samples - train_window_size - test_window_size + 1, step_size):
        train_end = start + train_window_size
        test_end = train_end + test_window_size

        if test_end <= n_samples:
            train_indices = indices[start:train_end]
            test_indices = indices[train_end:test_end]


            yield train_indices, test_indices

# %%
#Implement rolling-window time-series cross validation for hyperparameter grid search
val_scores_dict = defaultdict(list)

#Get a function to transfer the list types in params.items() to tuple types
#for further use when we use these tuples as the keys of val_scores_dict
def make_hashable(params):
    hashable_params = {}
    for key, value in params.items():
        if isinstance(value, list):
            hashable_params[key] = tuple(value)
        else:
            hashable_params[key] = value
    return hashable_params

# %% [markdown]
# **Neural Network model with 2 hidden layers**

# %%
simple_param_grid_nn_2 = {
    'model__optimizer': ['sgd', 'adam'],
    'model__learning_rate': [ 0.01, 0.001],
    'model__activation_func': ['relu', 'sigmoid'],
    'model__neurons_n': [[64, 32], [128, 64], [256, 128]],
    'model__dropout_rate': [0.0, 0.5],
    'model__regularize_terms': [None, l1(0.01), l2(0.01)]
}

# %%
#Neural Network 2 Function
def neural_net_2(input_shape, optimizer, learning_rate, activation_func, neurons_n, dropout_rate, regularize_terms, loss_func='mse', metrics_func=['mae']):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Dense(neurons_n[0], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_n[1], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(1))
    optimizer_instance = tf.keras.optimizers.get(optimizer)
    optimizer_instance.learning_rate = learning_rate
    model.compile(optimizer=optimizer_instance, loss=loss_func, metrics=metrics_func)
    return model

# %%
val_scores_dict_2 = defaultdict(list)

for train_indices, test_indices in tqdm(rolling_window_index_generator(X_train=X_train, step_size=n_train_window), file=sys.stdout):
    X_train_cv, y_train_cv = X_train[train_indices], y_train[train_indices]
    X_val_cv, y_val_cv = X_train[test_indices], y_train[test_indices]

    current_fold = np.zeros(X_train_cv.shape[0] + X_val_cv.shape[0])
    current_fold[:X_train_cv.shape[0]] = -1
    current_fold[X_train_cv.shape[0]:] = 0
    ps = skl.model_selection.PredefinedSplit(current_fold)

    X_combined = np.vstack((X_train_cv, X_val_cv))
    y_combined = np.concatenate((y_train_cv, y_val_cv))

    NN_2 = KerasRegressor(model=neural_net_2, input_shape=(X_combined.shape[1],), verbose=2)
    grid_2 = skl.model_selection.GridSearchCV(estimator=NN_2, param_grid=simple_param_grid_nn_2, scoring='neg_mean_squared_error', cv=ps, error_score='raise')
    grid_2.fit(X_combined, y_combined)

    for params, mean_score in zip(grid_2.cv_results_['params'], grid_2.cv_results_['mean_test_score']):
        hashable_params = make_hashable(params)
        val_scores_dict_2[tuple(hashable_params.items())].append(mean_score)

mean_val_scores_2 = {params: np.mean(scores) for params, scores in val_scores_dict_2.items()}
best_params_2 = min(mean_val_scores_2, key=mean_val_scores_2.get)
optimised_params_2 = dict(best_params_2)
print(f'Optimised hyperparameters for 2 layers: {optimised_params_2} & Average validation score: {mean_val_scores_2[best_params_2]}')
# Out:
# 0it [00:00, ?it/s]
# 1/1 - 1s - loss: 0.1068 - mae: 0.2574 - 642ms/epoch - 642ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 0s - loss: 8.9929 - mae: 0.1965 - 472ms/epoch - 472ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 0s - loss: 1.2632 - mae: 0.1960 - 374ms/epoch - 374ms/step
# 1/1 - 0s - 51ms/epoch - 51ms/step
# 1/1 - 1s - loss: 0.0429 - mae: 0.1907 - 595ms/epoch - 595ms/step
# 1/1 - 0s - 55ms/epoch - 55ms/step
# 1/1 - 1s - loss: 8.9527 - mae: 0.1276 - 585ms/epoch - 585ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 1.4203 - mae: 0.4237 - 551ms/epoch - 551ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0748 - mae: 0.1743 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - loss: 17.9455 - mae: 0.0839 - 398ms/epoch - 398ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.2015 - mae: 0.3793 - 330ms/epoch - 330ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.0224 - mae: 0.1035 - 514ms/epoch - 514ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 18.1339 - mae: 0.1104 - 568ms/epoch - 568ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.1522 - mae: 0.2709 - 532ms/epoch - 532ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - loss: 0.3695 - mae: 0.5980 - 340ms/epoch - 340ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 37.9035 - mae: 0.2600 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 3.2692 - mae: 0.2823 - 352ms/epoch - 352ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 0.0501 - mae: 0.1925 - 504ms/epoch - 504ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 37.7494 - mae: 0.1084 - 533ms/epoch - 533ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 3.4641 - mae: 0.4974 - 503ms/epoch - 503ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.0768 - mae: 0.2036 - 316ms/epoch - 316ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 9.0106 - mae: 0.2663 - 363ms/epoch - 363ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 1.3158 - mae: 0.2731 - 339ms/epoch - 339ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.0247 - mae: 0.1496 - 491ms/epoch - 491ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 9.0110 - mae: 0.1278 - 532ms/epoch - 532ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 1.3602 - mae: 0.3251 - 526ms/epoch - 526ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.0786 - mae: 0.2029 - 322ms/epoch - 322ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 18.1418 - mae: 0.2602 - 344ms/epoch - 344ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 2.0489 - mae: 0.1519 - 340ms/epoch - 340ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 0.0020 - mae: 0.0427 - 495ms/epoch - 495ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 18.0832 - mae: 0.1995 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 2.0336 - mae: 0.1025 - 518ms/epoch - 518ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.0779 - mae: 0.2250 - 301ms/epoch - 301ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 37.7843 - mae: 0.0905 - 362ms/epoch - 362ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 3.2691 - mae: 0.2386 - 323ms/epoch - 323ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 0.0648 - mae: 0.2507 - 501ms/epoch - 501ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 38.0446 - mae: 0.2869 - 559ms/epoch - 559ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 3.3070 - mae: 0.2078 - 500ms/epoch - 500ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.5489 - mae: 0.6267 - 383ms/epoch - 383ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 8.9681 - mae: 0.2622 - 416ms/epoch - 416ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.4309 - mae: 0.4003 - 380ms/epoch - 380ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.0146 - mae: 0.1018 - 529ms/epoch - 529ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 9.2502 - mae: 0.5339 - 557ms/epoch - 557ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 1.3527 - mae: 0.3752 - 593ms/epoch - 593ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.4104 - mae: 0.5417 - 350ms/epoch - 350ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 18.5047 - mae: 0.4615 - 398ms/epoch - 398ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 2.5669 - mae: 0.6877 - 1s/epoch - 1s/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 0.1652 - mae: 0.3357 - 534ms/epoch - 534ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 18.5790 - mae: 0.7101 - 574ms/epoch - 574ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 2.0494 - mae: 0.2113 - 570ms/epoch - 570ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.2064 - mae: 0.3941 - 351ms/epoch - 351ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 37.8532 - mae: 0.2520 - 394ms/epoch - 394ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 3.2445 - mae: 0.2144 - 384ms/epoch - 384ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.2741 - mae: 0.5206 - 511ms/epoch - 511ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 38.1702 - mae: 0.5165 - 563ms/epoch - 563ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 3.6657 - mae: 0.4515 - 552ms/epoch - 552ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.2303 - mae: 0.4237 - 353ms/epoch - 353ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 9.2017 - mae: 0.5588 - 393ms/epoch - 393ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 1.3163 - mae: 0.2865 - 385ms/epoch - 385ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 0.2010 - mae: 0.3898 - 566ms/epoch - 566ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 8.9839 - mae: 0.2794 - 585ms/epoch - 585ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 1.3456 - mae: 0.2357 - 580ms/epoch - 580ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0335 - mae: 0.1683 - 369ms/epoch - 369ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 0s - loss: 18.1295 - mae: 0.3294 - 412ms/epoch - 412ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 2.1668 - mae: 0.3629 - 390ms/epoch - 390ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.3021 - mae: 0.4415 - 559ms/epoch - 559ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 1s - loss: 18.1951 - mae: 0.3600 - 581ms/epoch - 581ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.2872 - mae: 0.4318 - 576ms/epoch - 576ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.1584 - mae: 0.3484 - 356ms/epoch - 356ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 38.2935 - mae: 0.4760 - 393ms/epoch - 393ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 3.2958 - mae: 0.3280 - 422ms/epoch - 422ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.2188 - mae: 0.4030 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 37.8489 - mae: 0.3695 - 600ms/epoch - 600ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 3.2851 - mae: 0.2661 - 539ms/epoch - 539ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0773 - mae: 0.2017 - 325ms/epoch - 325ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 10.7625 - mae: 1.3505 - 339ms/epoch - 339ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.3180 - mae: 0.2662 - 340ms/epoch - 340ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.1572 - mae: 0.3671 - 507ms/epoch - 507ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 10.0906 - mae: 1.0707 - 546ms/epoch - 546ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.5426 - mae: 1.1409 - 518ms/epoch - 518ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.0351 - mae: 0.1763 - 300ms/epoch - 300ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 18.1084 - mae: 0.3385 - 357ms/epoch - 357ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.0631 - mae: 0.1531 - 333ms/epoch - 333ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 0.0697 - mae: 0.1900 - 1s/epoch - 1s/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 19.0794 - mae: 1.0021 - 504ms/epoch - 504ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 2.3875 - mae: 0.5876 - 492ms/epoch - 492ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.6556 - mae: 0.7883 - 311ms/epoch - 311ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 38.1624 - mae: 0.4780 - 363ms/epoch - 363ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 3.2157 - mae: 0.1353 - 317ms/epoch - 317ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.4558 - mae: 0.6497 - 477ms/epoch - 477ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 38.7626 - mae: 0.9900 - 515ms/epoch - 515ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 7.8455 - mae: 2.1577 - 527ms/epoch - 527ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 1.7676 - mae: 1.3236 - 319ms/epoch - 319ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 10.6639 - mae: 1.3253 - 356ms/epoch - 356ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.2405 - mae: 0.1306 - 325ms/epoch - 325ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.3739 - mae: 0.5888 - 468ms/epoch - 468ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 9.2934 - mae: 0.6071 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 1.7064 - mae: 0.6787 - 494ms/epoch - 494ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.0328 - mae: 0.1436 - 296ms/epoch - 296ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 18.4127 - mae: 0.5688 - 351ms/epoch - 351ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.0733 - mae: 0.2131 - 350ms/epoch - 350ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.1016 - mae: 0.2736 - 480ms/epoch - 480ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 18.8223 - mae: 0.8695 - 529ms/epoch - 529ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.8162 - mae: 0.8966 - 558ms/epoch - 558ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.2442 - mae: 0.4578 - 303ms/epoch - 303ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 38.6767 - mae: 0.9159 - 344ms/epoch - 344ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.4282 - mae: 0.4553 - 336ms/epoch - 336ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.3412 - mae: 0.5568 - 471ms/epoch - 471ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 40.2478 - mae: 1.5856 - 541ms/epoch - 541ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.2308 - mae: 0.1549 - 518ms/epoch - 518ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.1859 - mae: 0.8503 - 348ms/epoch - 348ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 9.4665 - mae: 0.6869 - 388ms/epoch - 388ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 3.7804 - mae: 1.4258 - 397ms/epoch - 397ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 2.3823 - mae: 1.3730 - 546ms/epoch - 546ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 8.9096 - mae: 0.3234 - 565ms/epoch - 565ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 2.4669 - mae: 0.8194 - 578ms/epoch - 578ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 1.0039 - mae: 0.9902 - 378ms/epoch - 378ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - loss: 18.8711 - mae: 0.8006 - 404ms/epoch - 404ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 2.6697 - mae: 0.6131 - 379ms/epoch - 379ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 0.0851 - mae: 0.2695 - 532ms/epoch - 532ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 18.1757 - mae: 0.2765 - 588ms/epoch - 588ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.2177 - mae: 0.3808 - 591ms/epoch - 591ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 0.4623 - mae: 0.5424 - 996ms/epoch - 996ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 38.3404 - mae: 0.5424 - 409ms/epoch - 409ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 4.8301 - mae: 1.1006 - 392ms/epoch - 392ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.4986 - mae: 0.6252 - 519ms/epoch - 519ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 38.9257 - mae: 0.9125 - 579ms/epoch - 579ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.4131 - mae: 0.4481 - 575ms/epoch - 575ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.3346 - mae: 0.5674 - 343ms/epoch - 343ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 9.1594 - mae: 0.4516 - 398ms/epoch - 398ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 2.1715 - mae: 0.7884 - 399ms/epoch - 399ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 1.9083 - mae: 1.3746 - 534ms/epoch - 534ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 9.4511 - mae: 0.6904 - 585ms/epoch - 585ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 2.5213 - mae: 1.0171 - 549ms/epoch - 549ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.5373 - mae: 0.7061 - 357ms/epoch - 357ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 18.8228 - mae: 0.7952 - 393ms/epoch - 393ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 3.0861 - mae: 0.7700 - 404ms/epoch - 404ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 0.7000 - mae: 0.7048 - 552ms/epoch - 552ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 18.5681 - mae: 0.6046 - 563ms/epoch - 563ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 2.0175 - mae: 0.1299 - 555ms/epoch - 555ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 1.3536 - mae: 1.0211 - 351ms/epoch - 351ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 38.6182 - mae: 0.8221 - 390ms/epoch - 390ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 5.5375 - mae: 1.1719 - 395ms/epoch - 395ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 0.0484 - mae: 0.1944 - 521ms/epoch - 521ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 37.9518 - mae: 0.2187 - 582ms/epoch - 582ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 3.7455 - mae: 0.6039 - 567ms/epoch - 567ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 1s - loss: 0.1338 - mae: 0.2775 - 545ms/epoch - 545ms/step
# 1it [01:33, 93.38s/it]1/1 - 0s - loss: 0.2588 - mae: 0.4150 - 306ms/epoch - 306ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 8.9823 - mae: 0.2241 - 342ms/epoch - 342ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.7489 - mae: 0.6577 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.1223 - mae: 0.3015 - 462ms/epoch - 462ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 8.9224 - mae: 0.1602 - 531ms/epoch - 531ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 1.2550 - mae: 0.1178 - 509ms/epoch - 509ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.1601 - mae: 0.3617 - 310ms/epoch - 310ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 17.9867 - mae: 0.1450 - 352ms/epoch - 352ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.0198 - mae: 0.0742 - 336ms/epoch - 336ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 0.1678 - mae: 0.3876 - 487ms/epoch - 487ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 18.1126 - mae: 0.1463 - 507ms/epoch - 507ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.0415 - mae: 0.1518 - 492ms/epoch - 492ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.0967 - mae: 0.2640 - 304ms/epoch - 304ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 37.8780 - mae: 0.3491 - 360ms/epoch - 360ms/step
# 1/1 - 1s - 701ms/epoch - 701ms/step
# 1/1 - 0s - loss: 3.2081 - mae: 0.0776 - 322ms/epoch - 322ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.0567 - mae: 0.2051 - 507ms/epoch - 507ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 38.2310 - mae: 0.5553 - 523ms/epoch - 523ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.2135 - mae: 0.1133 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.1799 - mae: 0.3950 - 306ms/epoch - 306ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 9.1773 - mae: 0.4688 - 379ms/epoch - 379ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 1.3657 - mae: 0.3725 - 327ms/epoch - 327ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.0255 - mae: 0.1392 - 483ms/epoch - 483ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 9.1932 - mae: 0.4468 - 530ms/epoch - 530ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 1.4471 - mae: 0.4475 - 523ms/epoch - 523ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.1319 - mae: 0.2955 - 296ms/epoch - 296ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 18.0580 - mae: 0.2735 - 350ms/epoch - 350ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.0722 - mae: 0.2276 - 335ms/epoch - 335ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.1709 - mae: 0.3694 - 465ms/epoch - 465ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 18.1942 - mae: 0.2675 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.0216 - mae: 0.0656 - 493ms/epoch - 493ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.0368 - mae: 0.1874 - 301ms/epoch - 301ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 37.8578 - mae: 0.2486 - 343ms/epoch - 343ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.2134 - mae: 0.1518 - 322ms/epoch - 322ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.1654 - mae: 0.3595 - 488ms/epoch - 488ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 38.0547 - mae: 0.2641 - 519ms/epoch - 519ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.2049 - mae: 0.0335 - 507ms/epoch - 507ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.0939 - mae: 0.2544 - 357ms/epoch - 357ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 9.1352 - mae: 0.4272 - 400ms/epoch - 400ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.3070 - mae: 0.2102 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 0.7592 - mae: 0.7168 - 537ms/epoch - 537ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 9.0157 - mae: 0.2698 - 571ms/epoch - 571ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 1.7345 - mae: 0.4719 - 568ms/epoch - 568ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0653 - mae: 0.2166 - 355ms/epoch - 355ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 18.2718 - mae: 0.4834 - 388ms/epoch - 388ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 2.2156 - mae: 0.4420 - 376ms/epoch - 376ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 0.4213 - mae: 0.6201 - 518ms/epoch - 518ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 18.3085 - mae: 0.3588 - 574ms/epoch - 574ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 2.8325 - mae: 0.8943 - 551ms/epoch - 551ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.5339 - mae: 0.6709 - 358ms/epoch - 358ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 38.2698 - mae: 0.5060 - 409ms/epoch - 409ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 3.7136 - mae: 0.5341 - 377ms/epoch - 377ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 0.0729 - mae: 0.2483 - 544ms/epoch - 544ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 37.8864 - mae: 0.2607 - 1s/epoch - 1s/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.4434 - mae: 0.4905 - 544ms/epoch - 544ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.4945 - mae: 0.5771 - 351ms/epoch - 351ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 9.1295 - mae: 0.3421 - 386ms/epoch - 386ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.3373 - mae: 0.3010 - 377ms/epoch - 377ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 0.1717 - mae: 0.3666 - 512ms/epoch - 512ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 9.3331 - mae: 0.5241 - 584ms/epoch - 584ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 1.6725 - mae: 0.5786 - 550ms/epoch - 550ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.3828 - mae: 0.6104 - 373ms/epoch - 373ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 18.6894 - mae: 0.8821 - 419ms/epoch - 419ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.1509 - mae: 0.3471 - 402ms/epoch - 402ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.1622 - mae: 0.2653 - 597ms/epoch - 597ms/step
# 1/1 - 0s - 59ms/epoch - 59ms/step
# 1/1 - 1s - loss: 18.7098 - mae: 0.7885 - 625ms/epoch - 625ms/step
# 1/1 - 0s - 58ms/epoch - 58ms/step
# 1/1 - 1s - loss: 2.4216 - mae: 0.5963 - 571ms/epoch - 571ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.0153 - mae: 0.1106 - 373ms/epoch - 373ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 38.0862 - mae: 0.4814 - 407ms/epoch - 407ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - loss: 3.3097 - mae: 0.2776 - 411ms/epoch - 411ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 0.3788 - mae: 0.5150 - 561ms/epoch - 561ms/step
# 1/1 - 0s - 51ms/epoch - 51ms/step
# 1/1 - 1s - loss: 37.8573 - mae: 0.1997 - 597ms/epoch - 597ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.2398 - mae: 0.1426 - 610ms/epoch - 610ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0625 - mae: 0.1932 - 312ms/epoch - 312ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 9.7906 - mae: 0.9313 - 344ms/epoch - 344ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 2.6014 - mae: 1.1732 - 334ms/epoch - 334ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - loss: 0.0987 - mae: 0.2934 - 468ms/epoch - 468ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 10.1057 - mae: 1.0823 - 543ms/epoch - 543ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 1.3453 - mae: 0.3312 - 545ms/epoch - 545ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 0s - loss: 0.0400 - mae: 0.1686 - 340ms/epoch - 340ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 0s - loss: 18.4511 - mae: 0.5462 - 366ms/epoch - 366ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 2.0581 - mae: 0.1808 - 351ms/epoch - 351ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - loss: 1.2731 - mae: 1.1200 - 485ms/epoch - 485ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 18.8839 - mae: 0.9346 - 594ms/epoch - 594ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.1410 - mae: 0.3445 - 515ms/epoch - 515ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 0.3706 - mae: 0.5916 - 312ms/epoch - 312ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 38.3684 - mae: 0.6222 - 387ms/epoch - 387ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 3.2153 - mae: 0.1355 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 0.2071 - mae: 0.4285 - 525ms/epoch - 525ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 1s - loss: 38.0227 - mae: 0.3748 - 599ms/epoch - 599ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 3.2661 - mae: 0.2274 - 562ms/epoch - 562ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 0.6478 - mae: 0.7930 - 443ms/epoch - 443ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 9.1504 - mae: 0.4450 - 1s/epoch - 1s/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 0s - loss: 1.6078 - mae: 0.5998 - 401ms/epoch - 401ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 0.4601 - mae: 0.6569 - 537ms/epoch - 537ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 9.6530 - mae: 0.8878 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.8539 - mae: 0.7793 - 498ms/epoch - 498ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 0s - loss: 0.3595 - mae: 0.5861 - 324ms/epoch - 324ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 18.2081 - mae: 0.2682 - 355ms/epoch - 355ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.1048 - mae: 0.2751 - 342ms/epoch - 342ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 2.0182 - mae: 1.4135 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 18.2860 - mae: 0.4646 - 534ms/epoch - 534ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.3728 - mae: 0.5853 - 531ms/epoch - 531ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.2383 - mae: 0.4674 - 331ms/epoch - 331ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 38.6856 - mae: 0.8923 - 354ms/epoch - 354ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 3.5889 - mae: 0.6018 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 56ms/epoch - 56ms/step
# 1/1 - 1s - loss: 1.0085 - mae: 0.9946 - 529ms/epoch - 529ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 38.1401 - mae: 0.4876 - 600ms/epoch - 600ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 3.2541 - mae: 0.1941 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 1.3896 - mae: 1.1288 - 416ms/epoch - 416ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 8.9761 - mae: 0.2384 - 434ms/epoch - 434ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 0s - loss: 3.7996 - mae: 1.4822 - 408ms/epoch - 408ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 0.0794 - mae: 0.2127 - 550ms/epoch - 550ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 9.0999 - mae: 0.4253 - 613ms/epoch - 613ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 1.3860 - mae: 0.3066 - 635ms/epoch - 635ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 2.6284 - mae: 1.5555 - 428ms/epoch - 428ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 19.6059 - mae: 1.1482 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 3.5731 - mae: 1.0307 - 422ms/epoch - 422ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 1.9031 - mae: 1.2624 - 525ms/epoch - 525ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 18.3957 - mae: 0.5870 - 659ms/epoch - 659ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.2926 - mae: 0.4191 - 552ms/epoch - 552ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 1.0172 - mae: 0.9608 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 0s - loss: 38.0313 - mae: 0.4482 - 482ms/epoch - 482ms/step
# 1/1 - 0s - 55ms/epoch - 55ms/step
# 1/1 - 0s - loss: 3.4766 - mae: 0.4611 - 379ms/epoch - 379ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 0.4559 - mae: 0.6217 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 38.3918 - mae: 0.5407 - 683ms/epoch - 683ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 1s - loss: 3.3181 - mae: 0.3002 - 630ms/epoch - 630ms/step
# 1/1 - 0s - 51ms/epoch - 51ms/step
# 1/1 - 0s - loss: 0.6367 - mae: 0.6632 - 358ms/epoch - 358ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 9.3072 - mae: 0.5258 - 402ms/epoch - 402ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.6167 - mae: 0.5646 - 386ms/epoch - 386ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.1829 - mae: 0.3138 - 611ms/epoch - 611ms/step
# 1/1 - 0s - 56ms/epoch - 56ms/step
# 1/1 - 1s - loss: 9.0297 - mae: 0.3207 - 1s/epoch - 1s/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 2.0179 - mae: 0.8271 - 603ms/epoch - 603ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.4157 - mae: 0.5880 - 371ms/epoch - 371ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 18.8704 - mae: 0.6922 - 410ms/epoch - 410ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 0s - loss: 3.3977 - mae: 1.0698 - 463ms/epoch - 463ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 1.5673 - mae: 1.0784 - 686ms/epoch - 686ms/step
# 1/1 - 0s - 56ms/epoch - 56ms/step
# 1/1 - 1s - loss: 18.0569 - mae: 0.1263 - 674ms/epoch - 674ms/step
# 1/1 - 0s - 55ms/epoch - 55ms/step
# 1/1 - 1s - loss: 2.0327 - mae: 0.1304 - 647ms/epoch - 647ms/step
# 1/1 - 0s - 58ms/epoch - 58ms/step
# 1/1 - 1s - loss: 1.7706 - mae: 1.3029 - 539ms/epoch - 539ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 1s - loss: 41.2153 - mae: 1.8139 - 509ms/epoch - 509ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 3.4933 - mae: 0.4345 - 398ms/epoch - 398ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 1.5801 - mae: 1.2217 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 38.2569 - mae: 0.4515 - 561ms/epoch - 561ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 4.9838 - mae: 1.0217 - 546ms/epoch - 546ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 19.7220 - mae: 1.1256 - 577ms/epoch - 577ms/step
# 2it [03:08, 94.15s/it]1/1 - 0s - loss: 0.1557 - mae: 0.3744 - 317ms/epoch - 317ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 9.0372 - mae: 0.3930 - 346ms/epoch - 346ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.2274 - mae: 0.1088 - 327ms/epoch - 327ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 1s - loss: 0.3271 - mae: 0.5715 - 561ms/epoch - 561ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 8.8097 - mae: 0.1699 - 540ms/epoch - 540ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 1.2760 - mae: 0.1900 - 526ms/epoch - 526ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0369 - mae: 0.1700 - 309ms/epoch - 309ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - loss: 18.2263 - mae: 0.0937 - 365ms/epoch - 365ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.3364 - mae: 0.5392 - 346ms/epoch - 346ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.1201 - mae: 0.3194 - 834ms/epoch - 834ms/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 18.0793 - mae: 0.0689 - 722ms/epoch - 722ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 1s - loss: 2.2437 - mae: 0.4355 - 1s/epoch - 1s/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 0s - loss: 0.0445 - mae: 0.2048 - 484ms/epoch - 484ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 37.8113 - mae: 0.1211 - 569ms/epoch - 569ms/step
# 1/1 - 0s - 104ms/epoch - 104ms/step
# 1/1 - 0s - loss: 3.2297 - mae: 0.1688 - 474ms/epoch - 474ms/step
# 1/1 - 0s - 57ms/epoch - 57ms/step
# 1/1 - 1s - loss: 0.0249 - mae: 0.1208 - 578ms/epoch - 578ms/step
# 1/1 - 0s - 55ms/epoch - 55ms/step
# 1/1 - 1s - loss: 37.7551 - mae: 0.1941 - 712ms/epoch - 712ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 3.2457 - mae: 0.1617 - 548ms/epoch - 548ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.1586 - mae: 0.3451 - 381ms/epoch - 381ms/step
# 1/1 - 0s - 56ms/epoch - 56ms/step
# 1/1 - 0s - loss: 9.0412 - mae: 0.3176 - 395ms/epoch - 395ms/step
# 1/1 - 0s - 56ms/epoch - 56ms/step
# 1/1 - 0s - loss: 1.2786 - mae: 0.2200 - 362ms/epoch - 362ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 0.0624 - mae: 0.2312 - 528ms/epoch - 528ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 9.0349 - mae: 0.2238 - 579ms/epoch - 579ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 1.3160 - mae: 0.2279 - 582ms/epoch - 582ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.0617 - mae: 0.2240 - 331ms/epoch - 331ms/step
# 1/1 - 1s - 707ms/epoch - 707ms/step
# 1/1 - 0s - loss: 18.1061 - mae: 0.3566 - 391ms/epoch - 391ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 2.0466 - mae: 0.1503 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 0.3314 - mae: 0.5625 - 541ms/epoch - 541ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 1s - loss: 18.0517 - mae: 0.1226 - 603ms/epoch - 603ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 2.1280 - mae: 0.3270 - 570ms/epoch - 570ms/step
# 1/1 - 0s - 51ms/epoch - 51ms/step
# 1/1 - 0s - loss: 0.0308 - mae: 0.1393 - 351ms/epoch - 351ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 0s - loss: 37.9711 - mae: 0.2166 - 403ms/epoch - 403ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 0s - loss: 3.2305 - mae: 0.1574 - 399ms/epoch - 399ms/step
# 1/1 - 0s - 58ms/epoch - 58ms/step
# 1/1 - 1s - loss: 0.0271 - mae: 0.1587 - 747ms/epoch - 747ms/step
# 1/1 - 0s - 55ms/epoch - 55ms/step
# 1/1 - 1s - loss: 37.9523 - mae: 0.1967 - 703ms/epoch - 703ms/step
# 1/1 - 0s - 57ms/epoch - 57ms/step
# 1/1 - 1s - loss: 3.3337 - mae: 0.3302 - 675ms/epoch - 675ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 0s - loss: 0.1643 - mae: 0.2982 - 481ms/epoch - 481ms/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 10.0319 - mae: 0.8676 - 554ms/epoch - 554ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 0s - loss: 1.5538 - mae: 0.4395 - 440ms/epoch - 440ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 1s - loss: 0.2216 - mae: 0.3729 - 594ms/epoch - 594ms/step
# 1/1 - 0s - 55ms/epoch - 55ms/step
# 1/1 - 1s - loss: 9.0280 - mae: 0.2965 - 676ms/epoch - 676ms/step
# 1/1 - 0s - 53ms/epoch - 53ms/step
# 1/1 - 1s - loss: 1.5439 - mae: 0.4569 - 638ms/epoch - 638ms/step
# 1/1 - 0s - 57ms/epoch - 57ms/step
# 1/1 - 0s - loss: 0.0122 - mae: 0.0895 - 412ms/epoch - 412ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 0s - loss: 18.1306 - mae: 0.2209 - 471ms/epoch - 471ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 2.1438 - mae: 0.3060 - 435ms/epoch - 435ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 1s - loss: 0.0351 - mae: 0.1725 - 621ms/epoch - 621ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 18.1513 - mae: 0.2621 - 641ms/epoch - 641ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 1s - loss: 2.6102 - mae: 0.5072 - 679ms/epoch - 679ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 0s - loss: 0.2849 - mae: 0.4819 - 413ms/epoch - 413ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - loss: 37.7707 - mae: 0.2442 - 472ms/epoch - 472ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 0s - loss: 3.3844 - mae: 0.3947 - 409ms/epoch - 409ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 0.1017 - mae: 0.2894 - 559ms/epoch - 559ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 37.8373 - mae: 0.3165 - 628ms/epoch - 628ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 3.4344 - mae: 0.3226 - 660ms/epoch - 660ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 0.1321 - mae: 0.3110 - 373ms/epoch - 373ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 9.0767 - mae: 0.2426 - 453ms/epoch - 453ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 0s - loss: 2.0143 - mae: 0.8595 - 454ms/epoch - 454ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 0.1424 - mae: 0.3510 - 594ms/epoch - 594ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 8.9708 - mae: 0.3008 - 666ms/epoch - 666ms/step
# 1/1 - 0s - 50ms/epoch - 50ms/step
# 1/1 - 1s - loss: 1.4928 - mae: 0.4860 - 599ms/epoch - 599ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 0s - loss: 0.0742 - mae: 0.2392 - 380ms/epoch - 380ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 19.0203 - mae: 0.9932 - 466ms/epoch - 466ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 1s - loss: 2.1236 - mae: 0.2888 - 520ms/epoch - 520ms/step
# 1/1 - 0s - 56ms/epoch - 56ms/step
# 1/1 - 1s - loss: 0.5989 - mae: 0.7292 - 1s/epoch - 1s/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 1s - loss: 18.3424 - mae: 0.4856 - 701ms/epoch - 701ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 2.3426 - mae: 0.5118 - 618ms/epoch - 618ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 0s - loss: 0.1010 - mae: 0.2975 - 386ms/epoch - 386ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 38.0742 - mae: 0.4285 - 433ms/epoch - 433ms/step
# 1/1 - 0s - 51ms/epoch - 51ms/step
# 1/1 - 0s - loss: 3.3055 - mae: 0.2871 - 437ms/epoch - 437ms/step
# 1/1 - 0s - 54ms/epoch - 54ms/step
# 1/1 - 1s - loss: 0.1396 - mae: 0.3292 - 531ms/epoch - 531ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 38.0005 - mae: 0.3250 - 594ms/epoch - 594ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 3.3204 - mae: 0.3144 - 574ms/epoch - 574ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 0.2735 - mae: 0.5046 - 306ms/epoch - 306ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 9.3534 - mae: 0.6255 - 345ms/epoch - 345ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.5086 - mae: 0.5329 - 331ms/epoch - 331ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.1437 - mae: 0.3551 - 479ms/epoch - 479ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 9.2074 - mae: 0.4686 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 1.5431 - mae: 0.5455 - 503ms/epoch - 503ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.6448 - mae: 0.7903 - 314ms/epoch - 314ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 18.4428 - mae: 0.5708 - 336ms/epoch - 336ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 2.0017 - mae: 0.1444 - 334ms/epoch - 334ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.1590 - mae: 1.0676 - 474ms/epoch - 474ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 18.0750 - mae: 0.3281 - 519ms/epoch - 519ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.6968 - mae: 0.8205 - 503ms/epoch - 503ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 2.1027 - mae: 1.4434 - 295ms/epoch - 295ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 0s - loss: 39.1037 - mae: 1.1564 - 349ms/epoch - 349ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 3.4728 - mae: 0.5010 - 325ms/epoch - 325ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.7305 - mae: 0.8410 - 483ms/epoch - 483ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 38.3889 - mae: 0.8819 - 527ms/epoch - 527ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 3.4321 - mae: 0.4538 - 511ms/epoch - 511ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.1305 - mae: 0.3185 - 294ms/epoch - 294ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 8.9888 - mae: 0.1611 - 353ms/epoch - 353ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.2601 - mae: 0.1686 - 325ms/epoch - 325ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.0907 - mae: 0.2589 - 528ms/epoch - 528ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 9.0651 - mae: 0.2965 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 48ms/epoch - 48ms/step
# 1/1 - 0s - loss: 1.3122 - mae: 0.2952 - 497ms/epoch - 497ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 3.5341 - mae: 1.8744 - 323ms/epoch - 323ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 18.4069 - mae: 0.5455 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.0385 - mae: 0.1236 - 361ms/epoch - 361ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.3733 - mae: 0.5935 - 527ms/epoch - 527ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 18.5684 - mae: 0.7002 - 499ms/epoch - 499ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.0939 - mae: 0.2297 - 490ms/epoch - 490ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.3199 - mae: 0.5443 - 301ms/epoch - 301ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 37.9701 - mae: 0.2945 - 1s/epoch - 1s/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 3.3841 - mae: 0.4231 - 333ms/epoch - 333ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.0899 - mae: 0.2652 - 484ms/epoch - 484ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 37.6677 - mae: 0.1234 - 522ms/epoch - 522ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.3340 - mae: 0.3551 - 514ms/epoch - 514ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.2430 - mae: 1.0522 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 9.1672 - mae: 0.4989 - 398ms/epoch - 398ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.6618 - mae: 0.6021 - 381ms/epoch - 381ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 1.5480 - mae: 0.8572 - 515ms/epoch - 515ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 10.3652 - mae: 1.0508 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.0656 - mae: 0.8092 - 607ms/epoch - 607ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.4646 - mae: 0.5603 - 343ms/epoch - 343ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 19.2204 - mae: 0.8273 - 391ms/epoch - 391ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.8369 - mae: 0.9456 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 1.5720 - mae: 1.1921 - 528ms/epoch - 528ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 18.2135 - mae: 0.3063 - 549ms/epoch - 549ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.1871 - mae: 0.3481 - 563ms/epoch - 563ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.3729 - mae: 0.5319 - 357ms/epoch - 357ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 38.1534 - mae: 0.4315 - 414ms/epoch - 414ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 3.7864 - mae: 0.7160 - 378ms/epoch - 378ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 2.9545 - mae: 1.6254 - 553ms/epoch - 553ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 38.0955 - mae: 0.4629 - 586ms/epoch - 586ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 4.0484 - mae: 0.9074 - 551ms/epoch - 551ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 1.2439 - mae: 1.0820 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 10.0796 - mae: 0.9737 - 394ms/epoch - 394ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 0s - loss: 1.8103 - mae: 0.6810 - 385ms/epoch - 385ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 0.5358 - mae: 0.5780 - 519ms/epoch - 519ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 9.1529 - mae: 0.4516 - 563ms/epoch - 563ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 1.5499 - mae: 0.4610 - 541ms/epoch - 541ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.1597 - mae: 0.3548 - 358ms/epoch - 358ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 20.0107 - mae: 1.1364 - 390ms/epoch - 390ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.6499 - mae: 0.6305 - 392ms/epoch - 392ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 0.0223 - mae: 0.1177 - 505ms/epoch - 505ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 18.8722 - mae: 0.8220 - 581ms/epoch - 581ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 2.6833 - mae: 0.6493 - 553ms/epoch - 553ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 1.1618 - mae: 1.0613 - 342ms/epoch - 342ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 38.6206 - mae: 0.7809 - 388ms/epoch - 388ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 4.6901 - mae: 1.0219 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 0.3116 - mae: 0.4974 - 1s/epoch - 1s/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 40.3946 - mae: 1.4822 - 602ms/epoch - 602ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 3.3395 - mae: 0.3367 - 544ms/epoch - 544ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.0853 - mae: 0.2400 - 327ms/epoch - 327ms/step
# 3it [04:44, 95.24s/it]1/1 - 0s - loss: 0.0169 - mae: 0.1296 - 299ms/epoch - 299ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 8.9272 - mae: 0.1804 - 335ms/epoch - 335ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 1.2248 - mae: 0.1106 - 322ms/epoch - 322ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.7268 - mae: 0.6279 - 466ms/epoch - 466ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 9.5722 - mae: 0.5802 - 516ms/epoch - 516ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 1.2880 - mae: 0.1648 - 480ms/epoch - 480ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.2682 - mae: 0.4025 - 295ms/epoch - 295ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 18.2699 - mae: 0.4233 - 338ms/epoch - 338ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.5031 - mae: 0.6300 - 325ms/epoch - 325ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 2.2364 - mae: 1.1966 - 465ms/epoch - 465ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 18.1237 - mae: 0.2744 - 511ms/epoch - 511ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 2.0215 - mae: 0.0749 - 495ms/epoch - 495ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 0.0920 - mae: 0.2821 - 297ms/epoch - 297ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 38.0356 - mae: 0.4517 - 361ms/epoch - 361ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.2641 - mae: 0.2291 - 325ms/epoch - 325ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.7925 - mae: 0.6570 - 485ms/epoch - 485ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 38.0324 - mae: 0.3341 - 495ms/epoch - 495ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 3.4651 - mae: 0.4294 - 518ms/epoch - 518ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.0339 - mae: 0.1741 - 300ms/epoch - 300ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 8.9473 - mae: 0.1426 - 361ms/epoch - 361ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 3.0685 - mae: 1.1224 - 315ms/epoch - 315ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.0230 - mae: 0.9524 - 473ms/epoch - 473ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 9.6130 - mae: 0.6036 - 511ms/epoch - 511ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 2.4758 - mae: 0.7302 - 488ms/epoch - 488ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.2351 - mae: 0.3968 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 18.1026 - mae: 0.1512 - 345ms/epoch - 345ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.1059 - mae: 0.7766 - 318ms/epoch - 318ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.1249 - mae: 0.2736 - 473ms/epoch - 473ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 17.9878 - mae: 0.1541 - 518ms/epoch - 518ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.1494 - mae: 0.3514 - 503ms/epoch - 503ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 0s - loss: 0.4147 - mae: 0.5742 - 292ms/epoch - 292ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 37.8615 - mae: 0.2227 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.2831 - mae: 0.2270 - 318ms/epoch - 318ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.2893 - mae: 0.8386 - 473ms/epoch - 473ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 37.8389 - mae: 0.1308 - 516ms/epoch - 516ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 3.2694 - mae: 0.2619 - 491ms/epoch - 491ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.2203 - mae: 0.4533 - 356ms/epoch - 356ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 8.9248 - mae: 0.2524 - 407ms/epoch - 407ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 1.7855 - mae: 0.5840 - 419ms/epoch - 419ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.2619 - mae: 1.3140 - 543ms/epoch - 543ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 8.9693 - mae: 0.2836 - 574ms/epoch - 574ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 4.1341 - mae: 1.3721 - 540ms/epoch - 540ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.1471 - mae: 0.3072 - 350ms/epoch - 350ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 22.1816 - mae: 1.4974 - 373ms/epoch - 373ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 2.3549 - mae: 0.5001 - 375ms/epoch - 375ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 1.8074 - mae: 1.2217 - 534ms/epoch - 534ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 18.8365 - mae: 0.8380 - 554ms/epoch - 554ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.0725 - mae: 0.2815 - 536ms/epoch - 536ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.1594 - mae: 0.3947 - 355ms/epoch - 355ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# ...
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.8538 - mae: 0.7773 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 19.6873 - mae: 1.2319 - 376ms/epoch - 376ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.1686 - mae: 0.3467 - 360ms/epoch - 360ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 2.5329 - mae: 1.4213 - 506ms/epoch - 506ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 1s - loss: 18.1002 - mae: 0.3185 - 1s/epoch - 1s/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 2.2120 - mae: 0.3681 - 533ms/epoch - 533ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 1.2798 - mae: 1.0994 - 339ms/epoch - 339ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 38.7247 - mae: 0.8034 - 379ms/epoch - 379ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 3.4072 - mae: 0.3424 - 362ms/epoch - 362ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 1s - loss: 0.5541 - mae: 0.7433 - 513ms/epoch - 513ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 38.8407 - mae: 0.8703 - 544ms/epoch - 544ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 4.8398 - mae: 1.1449 - 527ms/epoch - 527ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 20.1386 - mae: 1.2445 - 526ms/epoch - 526ms/step
# 8it [12:20, 91.07s/it]1/1 - 0s - loss: 3.0460 - mae: 1.3396 - 280ms/epoch - 280ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 9.7372 - mae: 0.8304 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 2.5084 - mae: 0.9262 - 305ms/epoch - 305ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.7635 - mae: 0.8261 - 457ms/epoch - 457ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 1s - loss: 9.0253 - mae: 0.2569 - 512ms/epoch - 512ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 1.8392 - mae: 0.6505 - 483ms/epoch - 483ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.5914 - mae: 0.5438 - 283ms/epoch - 283ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 18.3737 - mae: 0.5324 - 321ms/epoch - 321ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 4.7847 - mae: 1.5677 - 313ms/epoch - 313ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.1166 - mae: 0.3337 - 458ms/epoch - 458ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 18.7628 - mae: 0.7864 - 494ms/epoch - 494ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.3847 - mae: 0.4930 - 462ms/epoch - 462ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - loss: 0.8572 - mae: 0.8920 - 287ms/epoch - 287ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 39.6722 - mae: 1.2432 - 327ms/epoch - 327ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 4.0609 - mae: 0.7769 - 308ms/epoch - 308ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.6280 - mae: 0.7532 - 457ms/epoch - 457ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 37.9234 - mae: 0.3428 - 500ms/epoch - 500ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 3.9257 - mae: 0.7096 - 501ms/epoch - 501ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 5.2541 - mae: 2.1039 - 278ms/epoch - 278ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 9.3883 - mae: 0.5747 - 326ms/epoch - 326ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 2.2372 - mae: 0.8307 - 304ms/epoch - 304ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 3.1351 - mae: 1.6249 - 474ms/epoch - 474ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 10.6481 - mae: 1.2750 - 487ms/epoch - 487ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - loss: 1.9834 - mae: 0.7214 - 467ms/epoch - 467ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 4.1163 - mae: 1.8386 - 290ms/epoch - 290ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 19.2842 - mae: 0.8192 - 327ms/epoch - 327ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 2.1431 - mae: 0.3245 - 310ms/epoch - 310ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 1.9831 - mae: 1.0154 - 452ms/epoch - 452ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 18.7400 - mae: 0.7678 - 498ms/epoch - 498ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 2.2193 - mae: 0.4306 - 470ms/epoch - 470ms/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - loss: 0.3265 - mae: 0.5297 - 276ms/epoch - 276ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 37.9935 - mae: 0.5536 - 315ms/epoch - 315ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 4.4120 - mae: 1.0743 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 1.7839 - mae: 1.1778 - 461ms/epoch - 461ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 38.1178 - mae: 0.5814 - 478ms/epoch - 478ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 5.0499 - mae: 1.2444 - 454ms/epoch - 454ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 5.9884 - mae: 2.1962 - 341ms/epoch - 341ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 33.0471 - mae: 3.6973 - 373ms/epoch - 373ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 6.9502 - mae: 2.3861 - 358ms/epoch - 358ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.0666 - mae: 1.3166 - 498ms/epoch - 498ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 15.2049 - mae: 2.0905 - 529ms/epoch - 529ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 3.3090 - mae: 1.1500 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 5.2648 - mae: 1.7467 - 331ms/epoch - 331ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 20.2751 - mae: 1.4681 - 375ms/epoch - 375ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 13.1557 - mae: 2.8578 - 361ms/epoch - 361ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 5.8850 - mae: 2.2078 - 521ms/epoch - 521ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 20.9365 - mae: 1.4008 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 3.4764 - mae: 1.0493 - 517ms/epoch - 517ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.3027 - mae: 0.4844 - 332ms/epoch - 332ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 40.3838 - mae: 1.5279 - 362ms/epoch - 362ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 6.7789 - mae: 1.7202 - 353ms/epoch - 353ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 1.4376 - mae: 1.0303 - 496ms/epoch - 496ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 40.5949 - mae: 1.5888 - 545ms/epoch - 545ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 7.2582 - mae: 1.7642 - 526ms/epoch - 526ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 5.6346 - mae: 2.1552 - 334ms/epoch - 334ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 22.1582 - mae: 3.0524 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 5.9287 - mae: 1.8906 - 356ms/epoch - 356ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 3.1595 - mae: 1.7421 - 491ms/epoch - 491ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 18.4114 - mae: 2.6304 - 526ms/epoch - 526ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 6.0780 - mae: 1.8294 - 528ms/epoch - 528ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 3.2524 - mae: 1.1447 - 334ms/epoch - 334ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 24.4276 - mae: 1.9218 - 374ms/epoch - 374ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 7.8014 - mae: 2.2614 - 348ms/epoch - 348ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 11.9346 - mae: 3.2665 - 504ms/epoch - 504ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 18.5208 - mae: 0.6210 - 537ms/epoch - 537ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 2.7196 - mae: 0.5370 - 525ms/epoch - 525ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 5.5454 - mae: 1.8316 - 333ms/epoch - 333ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 39.1285 - mae: 0.9675 - 368ms/epoch - 368ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 5.0987 - mae: 1.2140 - 354ms/epoch - 354ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 3.7409 - mae: 1.8464 - 501ms/epoch - 501ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 39.6883 - mae: 1.1033 - 544ms/epoch - 544ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 9.6497 - mae: 1.9938 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.9057 - mae: 0.9316 - 286ms/epoch - 286ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 1s - loss: 9.0302 - mae: 0.3956 - 1s/epoch - 1s/step
# 1/1 - 0s - 36ms/epoch - 36ms/step
# 1/1 - 0s - loss: 1.4051 - mae: 0.4030 - 307ms/epoch - 307ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.2968 - mae: 0.5168 - 454ms/epoch - 454ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 9.0213 - mae: 0.4292 - 475ms/epoch - 475ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 1.4071 - mae: 0.4144 - 474ms/epoch - 474ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.1321 - mae: 0.3341 - 281ms/epoch - 281ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 18.0633 - mae: 0.2137 - 324ms/epoch - 324ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 2.1715 - mae: 0.3712 - 301ms/epoch - 301ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 0.4133 - mae: 0.6323 - 450ms/epoch - 450ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 18.2345 - mae: 0.3205 - 484ms/epoch - 484ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 2.2222 - mae: 0.4324 - 469ms/epoch - 469ms/step
# 1/1 - 0s - 37ms/epoch - 37ms/step
# 1/1 - 0s - loss: 0.8347 - mae: 0.9057 - 284ms/epoch - 284ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 38.0411 - mae: 0.2482 - 329ms/epoch - 329ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 3.6047 - mae: 0.6031 - 311ms/epoch - 311ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.4210 - mae: 0.6171 - 446ms/epoch - 446ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 37.8499 - mae: 0.2340 - 486ms/epoch - 486ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.2336 - mae: 0.1674 - 477ms/epoch - 477ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 0.9480 - mae: 0.9540 - 285ms/epoch - 285ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 10.0103 - mae: 1.0474 - 328ms/epoch - 328ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 1.9207 - mae: 0.8031 - 302ms/epoch - 302ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.2051 - mae: 0.3998 - 457ms/epoch - 457ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 8.9091 - mae: 0.1849 - 487ms/epoch - 487ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.1568 - mae: 0.9382 - 477ms/epoch - 477ms/step
# 1/1 - 0s - 52ms/epoch - 52ms/step
# 1/1 - 0s - loss: 0.8431 - mae: 0.8855 - 291ms/epoch - 291ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 18.4996 - mae: 0.7296 - 327ms/epoch - 327ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 2.2631 - mae: 0.4604 - 298ms/epoch - 298ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 0.0233 - mae: 0.1334 - 456ms/epoch - 456ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 25.1674 - mae: 2.6425 - 475ms/epoch - 475ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 4.3658 - mae: 1.5321 - 464ms/epoch - 464ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.2766 - mae: 0.4893 - 288ms/epoch - 288ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 38.3426 - mae: 0.7527 - 326ms/epoch - 326ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 3.8240 - mae: 0.7816 - 312ms/epoch - 312ms/step
# 1/1 - 0s - 38ms/epoch - 38ms/step
# 1/1 - 0s - loss: 1.8794 - mae: 1.3628 - 451ms/epoch - 451ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 41.0087 - mae: 1.7735 - 461ms/epoch - 461ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 3.4600 - mae: 0.5011 - 495ms/epoch - 495ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.6468 - mae: 0.7400 - 332ms/epoch - 332ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 10.0736 - mae: 0.8977 - 395ms/epoch - 395ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 1.3857 - mae: 0.3084 - 357ms/epoch - 357ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 0.8421 - mae: 0.9110 - 494ms/epoch - 494ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 9.3339 - mae: 0.6342 - 543ms/epoch - 543ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 4.6466 - mae: 1.8003 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 1.8699 - mae: 1.2979 - 332ms/epoch - 332ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 1s - loss: 18.9843 - mae: 0.8004 - 1s/epoch - 1s/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 3.3027 - mae: 1.0318 - 353ms/epoch - 353ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 0.3317 - mae: 0.4701 - 505ms/epoch - 505ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 19.3034 - mae: 1.0905 - 539ms/epoch - 539ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 2.1534 - mae: 0.3595 - 526ms/epoch - 526ms/step
# 1/1 - 0s - 39ms/epoch - 39ms/step
# 1/1 - 0s - loss: 0.9167 - mae: 0.9424 - 330ms/epoch - 330ms/step
# 1/1 - 0s - 45ms/epoch - 45ms/step
# 1/1 - 0s - loss: 38.4376 - mae: 0.6535 - 371ms/epoch - 371ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 3.6735 - mae: 0.5616 - 353ms/epoch - 353ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.0018 - mae: 0.0396 - 495ms/epoch - 495ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 1s - loss: 38.8988 - mae: 0.8738 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 5.8367 - mae: 1.4639 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 0.2019 - mae: 0.4088 - 334ms/epoch - 334ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 10.8372 - mae: 1.2734 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 1.7867 - mae: 0.6715 - 352ms/epoch - 352ms/step
# 1/1 - 0s - 44ms/epoch - 44ms/step
# 1/1 - 0s - loss: 0.1119 - mae: 0.3243 - 497ms/epoch - 497ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 9.9504 - mae: 1.0097 - 540ms/epoch - 540ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 2.6291 - mae: 0.9728 - 520ms/epoch - 520ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 0s - loss: 1.6518 - mae: 1.1569 - 333ms/epoch - 333ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 21.8569 - mae: 1.8560 - 372ms/epoch - 372ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 3.5137 - mae: 1.1883 - 350ms/epoch - 350ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 0.4766 - mae: 0.5741 - 493ms/epoch - 493ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 1s - loss: 21.4959 - mae: 1.6058 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 1s - loss: 3.3225 - mae: 0.8366 - 528ms/epoch - 528ms/step
# 1/1 - 0s - 43ms/epoch - 43ms/step
# 1/1 - 0s - loss: 0.4923 - mae: 0.5467 - 335ms/epoch - 335ms/step
# 1/1 - 0s - 42ms/epoch - 42ms/step
# 1/1 - 0s - loss: 37.9130 - mae: 0.2034 - 382ms/epoch - 382ms/step
# 1/1 - 0s - 41ms/epoch - 41ms/step
# 1/1 - 0s - loss: 4.6689 - mae: 0.9703 - 365ms/epoch - 365ms/step
# 1/1 - 0s - 47ms/epoch - 47ms/step
# 1/1 - 1s - loss: 0.0729 - mae: 0.2340 - 530ms/epoch - 530ms/step
# 1/1 - 0s - 46ms/epoch - 46ms/step
# 1/1 - 1s - loss: 40.2086 - mae: 1.5176 - 671ms/epoch - 671ms/step
# 1/1 - 0s - 49ms/epoch - 49ms/step
# 1/1 - 1s - loss: 3.6037 - mae: 0.5430 - 592ms/epoch - 592ms/step
# 1/1 - 0s - 40ms/epoch - 40ms/step
# 1/1 - 1s - loss: 4.6590 - mae: 2.1027 - 575ms/epoch - 575ms/step
# 9it [13:44, 91.56s/it]
# Optimised hyperparameters for 2 layers: {'model__activation_func': 'sigmoid', 'model__dropout_rate': 0.0, 'model__learning_rate': 0.01, 'model__neurons_n': (256, 128), 'model__optimizer': 'adam', 'model__regularize_terms': None} & Average validation score: -13.771221346470789

# %%
#Train models with optimised hyperparameters
NN_2 = neural_net_2(input_shape=(X_train.shape[1],),
                    optimizer=optimised_params_2['model__optimizer'],
                    learning_rate=optimised_params_2['model__learning_rate'],
                    activation_func=optimised_params_2['model__activation_func'],
                    dropout_rate=optimised_params_2['model__dropout_rate'],
                    neurons_n=optimised_params_2['model__neurons_n'],
                    regularize_terms=optimised_params_2['model__regularize_terms'])

# %%
X_NN = original_data.drop(['ret','excess_ret','rfree','permno','date'], axis=1)
y_NN = original_data['excess_ret']
date = original_data['date']

# %%
def expanding_window_indices(start_date, end_date, step_size='1Y', val_size='4Y', test_size='1Y'):
    date_range = pd.date_range(start=start_date, end=end_date, freq=step_size)
    indices = []
    for end_val in date_range:
        start = pd.Timestamp(start_date)
        end_train = end_val - pd.DateOffset(years=int(test_size[:-1])) - pd.DateOffset(years=int(val_size[:-1]))
        if end_train < start:
            continue
        train_mask = (date >= start) & (date <= end_train)
        val_mask = (date > end_train) & (date <= (end_train + pd.DateOffset(years=int(val_size[:-1]))))
        test_mask = (date > (end_train + pd.DateOffset(years=int(val_size[:-1])))) & (date <= end_val)
        if test_mask.any():
            indices.append((train_mask, val_mask, test_mask))
    return indices

# Generate the expanding window indices
expanding_indices = expanding_window_indices('1986-02-01', '2016-12-01')

# %%
r2_oos_2 = []

for train_mask, val_mask, test_mask in tqdm(expanding_indices):
    X_train, y_train = X_NN.loc[train_mask].values, y_NN.loc[train_mask].values
    X_val, y_val = X_NN.loc[val_mask].values, y_NN.loc[val_mask].values
    X_test, y_test = X_NN.loc[test_mask].values, y_NN.loc[test_mask].values
    
    NN2_history = NN_2.fit(X_train, y_train, epochs=100, batch_size=10000,
                           validation_data=(X_val, y_val), verbose=0,
                           callbacks=[EarlyStopping(patience=2, restore_best_weights=True)])
    
    predictions = NN_2.predict(X_test)
    ss_res = np.sum((y_test - predictions.T) ** 2)
    ss_tot = np.sum((y_test) ** 2)
    r2_out_of_sample = 1 - (ss_res / ss_tot)
    r2_oos_2.append(r2_out_of_sample)

r2_oos_2_mean = np.mean(r2_oos_2)
print(r2_oos_2_mean)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# 2494/2494 [==============================] - 6s 3ms/step
#   4%|▍         | 1/25 [00:21<08:32, 21.35s/it]
# 2551/2551 [==============================] - 7s 3ms/step
#   8%|▊         | 2/25 [00:50<09:59, 26.05s/it]
# 2705/2705 [==============================] - 7s 2ms/step
#  12%|█▏        | 3/25 [01:37<13:02, 35.59s/it]

# %% [markdown]
# **Neural Network model with 3 hidden layers**

# %%
simple_param_grid_nn_3 = {
                 'model__optimizer': ['adam', 'sgd'],
                 'model__learning_rate': [0.01, 0.001],
                 'model__activation_func': ['relu', 'sigmoid'],
                 'model__neurons_n': [[64, 32, 16], [128, 64, 32]],
                 'model__dropout_rate': [0.0, 0.5],
                 'model__regularize_terms': [None, l1(0.01), l2(0.01)]
                 }

# %%
#Neural Network 3 Function
def neural_net_3(input_shape, optimizer, learning_rate, activation_func, neurons_n, dropout_rate, regularize_terms, loss_func='mse', metrics_func=['mae']):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Dense(neurons_n[0], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_n[1], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_n[2], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(1))
    optimizer_instance = tf.keras.optimizers.get(optimizer)
    optimizer_instance.learning_rate = learning_rate
    model.compile(optimizer=optimizer_instance, loss=loss_func, metrics=metrics_func)

    return model

# %%
for train_indices, test_indices in tqdm(rolling_window_index_generator(X_train=X_train, step_size=n_train_window), file=sys.stdout):  # n_test_window?
    X_train_cv, y_train_cv = X_train[train_indices], y_train[train_indices]
    
    X_val_cv, y_val_cv = X_train[test_indices], y_train[test_indices]

    current_fold = np.zeros(X_train_cv.shape[0] + X_val_cv.shape[0])
    current_fold[:X_train_cv.shape[0]] = -1 #-1 indicates training set
    current_fold[X_train_cv.shape[0]:] = 0 #0 indicates validation set
    ps = skl.model_selection.PredefinedSplit(current_fold)

    X_combined = np.vstack((X_train_cv, X_val_cv))
    y_combined = np.concatenate((y_train_cv, y_val_cv))

    NN_3 = KerasRegressor(model=neural_net_3, input_shape=(X_combined.shape[1],), verbose=2)
    #print("Available parameters for NN_3: ", NN_3.get_params().keys())
    grid = skl.model_selection.GridSearchCV(estimator=NN_3, param_grid=simple_param_grid_nn_3, scoring='neg_mean_squared_error', cv=ps, error_score='raise')
    grid.fit(X_combined, y_combined)

    #Record the best hyperparameters on average by validation scores across all validation observations (e.g., 1 validation set) within 1 rolling window
    for params, mean_score in zip(grid.cv_results_['params'], grid.cv_results_['mean_test_score']):
        hashable_params = make_hashable(params)
        val_scores_dict[tuple(hashable_params.items())].append(mean_score)
# Out:
# 0it [00:00, ?it/s]1/1 - 3s - loss: 0.0833 - mae: 0.2260 - 3s/epoch - 3s/step
# 1/1 - 0s - 213ms/epoch - 213ms/step
# 1/1 - 1s - loss: 9.8324 - mae: 0.1371 - 1s/epoch - 1s/step
# 1/1 - 0s - 129ms/epoch - 129ms/step
# 1/1 - 1s - loss: 1.4962 - mae: 0.1939 - 1s/epoch - 1s/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 0.1356 - mae: 0.3137 - 598ms/epoch - 598ms/step
# 1/1 - 0s - 119ms/epoch - 119ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x0000013D0F5F7670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 - 1s - loss: 9.9193 - mae: 0.1768 - 625ms/epoch - 625ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000013D0F61DB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 - 0s - 80ms/epoch - 80ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x0000013D10702CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 - 1s - loss: 1.4645 - mae: 0.1375 - 846ms/epoch - 846ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000013D10702160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 0.0178 - mae: 0.1090 - 1s/epoch - 1s/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 20.6079 - mae: 0.3571 - 1s/epoch - 1s/step
# 1/1 - 0s - 101ms/epoch - 101ms/step
# 1/1 - 1s - loss: 2.5413 - mae: 0.2590 - 1s/epoch - 1s/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 0.0316 - mae: 0.1736 - 616ms/epoch - 616ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 20.4609 - mae: 0.1560 - 743ms/epoch - 743ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 2.4666 - mae: 0.1239 - 760ms/epoch - 760ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 0.0586 - mae: 0.2256 - 1s/epoch - 1s/step
# 1/1 - 0s - 108ms/epoch - 108ms/step
# 1/1 - 1s - loss: 9.8630 - mae: 0.2192 - 1s/epoch - 1s/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 1.4788 - mae: 0.2094 - 1s/epoch - 1s/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 1s - loss: 0.1029 - mae: 0.2670 - 601ms/epoch - 601ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 10.0299 - mae: 0.2873 - 592ms/epoch - 592ms/step
# 1/1 - 0s - 93ms/epoch - 93ms/step
# 1/1 - 1s - loss: 1.4394 - mae: 0.1034 - 685ms/epoch - 685ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 0.0275 - mae: 0.1385 - 935ms/epoch - 935ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 20.7927 - mae: 0.3720 - 1s/epoch - 1s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 2.4583 - mae: 0.0890 - 1s/epoch - 1s/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 0.0696 - mae: 0.2499 - 540ms/epoch - 540ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 20.7403 - mae: 0.3071 - 742ms/epoch - 742ms/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 1s - loss: 2.4555 - mae: 0.1524 - 717ms/epoch - 717ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 0.5194 - mae: 0.5118 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 10.3582 - mae: 0.6446 - 1s/epoch - 1s/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 1.7305 - mae: 0.4224 - 1s/epoch - 1s/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 1s - loss: 0.0231 - mae: 0.1187 - 763ms/epoch - 763ms/step
# 1/1 - 0s - 149ms/epoch - 149ms/step
# 1/1 - 1s - loss: 10.2409 - mae: 0.5529 - 809ms/epoch - 809ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 1.8257 - mae: 0.4982 - 628ms/epoch - 628ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 1.1094 - mae: 0.9347 - 1s/epoch - 1s/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 20.7288 - mae: 0.2861 - 1s/epoch - 1s/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 1s - loss: 3.8695 - mae: 0.7391 - 1s/epoch - 1s/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 1s - loss: 0.0567 - mae: 0.1998 - 668ms/epoch - 668ms/step
# 1/1 - 0s - 103ms/epoch - 103ms/step
# 1/1 - 1s - loss: 20.6553 - mae: 0.1894 - 841ms/epoch - 841ms/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 1s - loss: 2.5535 - mae: 0.2614 - 1s/epoch - 1s/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 0.1313 - mae: 0.2872 - 883ms/epoch - 883ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 10.3049 - mae: 0.6490 - 1s/epoch - 1s/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 1.7268 - mae: 0.3728 - 1s/epoch - 1s/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 0.0567 - mae: 0.2345 - 839ms/epoch - 839ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 9.8683 - mae: 0.3578 - 746ms/epoch - 746ms/step
# 1/1 - 0s - 121ms/epoch - 121ms/step
# 1/1 - 1s - loss: 1.6213 - mae: 0.3898 - 725ms/epoch - 725ms/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 0.0111 - mae: 0.0731 - 1s/epoch - 1s/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 20.7040 - mae: 0.2000 - 1s/epoch - 1s/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 2.6792 - mae: 0.4500 - 1s/epoch - 1s/step
# 1/1 - 0s - 167ms/epoch - 167ms/step
# 1/1 - 1s - loss: 0.2382 - mae: 0.3586 - 784ms/epoch - 784ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 21.0067 - mae: 0.5813 - 724ms/epoch - 724ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 2.7142 - mae: 0.3805 - 820ms/epoch - 820ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 1.2613 - mae: 1.1111 - 1s/epoch - 1s/step
# 1/1 - 0s - 121ms/epoch - 121ms/step
# 1/1 - 1s - loss: 9.9822 - mae: 0.3577 - 1s/epoch - 1s/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 1.5265 - mae: 0.2503 - 1s/epoch - 1s/step
# 1/1 - 0s - 190ms/epoch - 190ms/step
# 1/1 - 1s - loss: 0.0586 - mae: 0.1755 - 560ms/epoch - 560ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 9.9044 - mae: 0.1731 - 735ms/epoch - 735ms/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 2.4804 - mae: 1.0108 - 672ms/epoch - 672ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 0.6005 - mae: 0.7574 - 1s/epoch - 1s/step
# 1/1 - 0s - 91ms/epoch - 91ms/step
# 1/1 - 1s - loss: 20.9056 - mae: 0.5334 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 2.7106 - mae: 0.5034 - 1s/epoch - 1s/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 0.2610 - mae: 0.4830 - 563ms/epoch - 563ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 21.3350 - mae: 0.8871 - 692ms/epoch - 692ms/step
# 1/1 - 0s - 111ms/epoch - 111ms/step
# 1/1 - 1s - loss: 2.5551 - mae: 0.3233 - 608ms/epoch - 608ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 0.4165 - mae: 0.6233 - 1s/epoch - 1s/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 10.2010 - mae: 0.6724 - 1s/epoch - 1s/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 1.5278 - mae: 0.2728 - 1s/epoch - 1s/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 0.1015 - mae: 0.2711 - 626ms/epoch - 626ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 9.7502 - mae: 0.1365 - 860ms/epoch - 860ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 1.4494 - mae: 0.1571 - 662ms/epoch - 662ms/step
# 1/1 - 0s - 101ms/epoch - 101ms/step
# 1/1 - 1s - loss: 0.0688 - mae: 0.2172 - 1s/epoch - 1s/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 21.3730 - mae: 0.7911 - 946ms/epoch - 946ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 3.5280 - mae: 1.0295 - 1s/epoch - 1s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 0.0503 - mae: 0.1651 - 640ms/epoch - 640ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 20.5343 - mae: 0.1544 - 772ms/epoch - 772ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 2.7931 - mae: 0.5713 - 872ms/epoch - 872ms/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 2.0886 - mae: 1.2830 - 1s/epoch - 1s/step
# 1/1 - 1s - 509ms/epoch - 509ms/step
# 1/1 - 1s - loss: 10.5838 - mae: 0.7500 - 1s/epoch - 1s/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 1.7091 - mae: 0.4639 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 1.1431 - mae: 1.0325 - 805ms/epoch - 805ms/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 1s - loss: 11.2360 - mae: 1.0505 - 787ms/epoch - 787ms/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 1.5404 - mae: 0.2615 - 761ms/epoch - 761ms/step
# 1/1 - 0s - 124ms/epoch - 124ms/step
# 1/1 - 1s - loss: 0.7341 - mae: 0.8090 - 1s/epoch - 1s/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 21.5001 - mae: 0.8035 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 3.8645 - mae: 1.1472 - 1s/epoch - 1s/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 0.9256 - mae: 0.8518 - 777ms/epoch - 777ms/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 23.6602 - mae: 1.5695 - 927ms/epoch - 927ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 3.2321 - mae: 0.7716 - 881ms/epoch - 881ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 1.3491 - mae: 1.0604 - 1s/epoch - 1s/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 10.1179 - mae: 0.5865 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 1.6887 - mae: 0.4052 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 2.1499 - mae: 1.3631 - 735ms/epoch - 735ms/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 11.3365 - mae: 0.9994 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 4.1243 - mae: 1.4565 - 906ms/epoch - 906ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 1.2594 - mae: 0.8320 - 1s/epoch - 1s/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 21.5159 - mae: 0.8997 - 1s/epoch - 1s/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 2.8635 - mae: 0.4880 - 1s/epoch - 1s/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 0.5027 - mae: 0.5942 - 787ms/epoch - 787ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 21.0578 - mae: 0.6564 - 802ms/epoch - 802ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 2.5990 - mae: 0.3704 - 951ms/epoch - 951ms/step
# 1/1 - 0s - 93ms/epoch - 93ms/step
# 1/1 - 2s - loss: 10.6169 - mae: 0.6883 - 2s/epoch - 2s/step
# 1it [02:09, 129.26s/it]1/1 - 1s - loss: 0.0405 - mae: 0.1606 - 1s/epoch - 1s/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 9.9453 - mae: 0.4118 - 1s/epoch - 1s/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 2.3387 - mae: 0.7977 - 1s/epoch - 1s/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 1s - loss: 0.0243 - mae: 0.1278 - 707ms/epoch - 707ms/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 9.9289 - mae: 0.1743 - 617ms/epoch - 617ms/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 1.4754 - mae: 0.2069 - 653ms/epoch - 653ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 0.1417 - mae: 0.3664 - 1s/epoch - 1s/step
# 1/1 - 0s - 102ms/epoch - 102ms/step
# 1/1 - 1s - loss: 20.6989 - mae: 0.3042 - 1s/epoch - 1s/step
# 1/1 - 0s - 122ms/epoch - 122ms/step
# 1/1 - 1s - loss: 2.6497 - mae: 0.4821 - 1s/epoch - 1s/step
# 1/1 - 0s - 138ms/epoch - 138ms/step
# 1/1 - 1s - loss: 0.1205 - mae: 0.3129 - 610ms/epoch - 610ms/step
# 1/1 - 0s - 149ms/epoch - 149ms/step
# 1/1 - 1s - loss: 20.6362 - mae: 0.1762 - 710ms/epoch - 710ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 2.4920 - mae: 0.1905 - 837ms/epoch - 837ms/step
# 1/1 - 0s - 101ms/epoch - 101ms/step
# 1/1 - 1s - loss: 0.1159 - mae: 0.3159 - 945ms/epoch - 945ms/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 9.8706 - mae: 0.1268 - 1s/epoch - 1s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 1.6073 - mae: 0.3742 - 1s/epoch - 1s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 0.0587 - mae: 0.2083 - 602ms/epoch - 602ms/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 1s - loss: 9.7698 - mae: 0.1779 - 804ms/epoch - 804ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 1.4801 - mae: 0.1919 - 616ms/epoch - 616ms/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 0.0295 - mae: 0.1483 - 979ms/epoch - 979ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 20.6407 - mae: 0.3204 - 1s/epoch - 1s/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 2.4722 - mae: 0.0936 - 898ms/epoch - 898ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 0.0381 - mae: 0.1542 - 581ms/epoch - 581ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 20.6344 - mae: 0.2169 - 622ms/epoch - 622ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 2.4364 - mae: 0.0940 - 603ms/epoch - 603ms/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 0.5210 - mae: 0.6645 - 1s/epoch - 1s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 17.2922 - mae: 2.3602 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 1.6800 - mae: 0.3490 - 1s/epoch - 1s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 0.3208 - mae: 0.4472 - 585ms/epoch - 585ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 10.1613 - mae: 0.4700 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 1.5234 - mae: 0.2949 - 692ms/epoch - 692ms/step
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 1s - loss: 0.7137 - mae: 0.7102 - 962ms/epoch - 962ms/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 20.5638 - mae: 0.2947 - 1s/epoch - 1s/step
# 1/1 - 0s - 103ms/epoch - 103ms/step
# 1/1 - 1s - loss: 2.4929 - mae: 0.2022 - 1s/epoch - 1s/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 0.3590 - mae: 0.5041 - 773ms/epoch - 773ms/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 21.0035 - mae: 0.4535 - 982ms/epoch - 982ms/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 3.0896 - mae: 0.6089 - 807ms/epoch - 807ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 0.1328 - mae: 0.3609 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 11.0449 - mae: 0.8605 - 1s/epoch - 1s/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 2s - loss: 2.0277 - mae: 0.6037 - 2s/epoch - 2s/step
# 1/1 - 0s - 179ms/epoch - 179ms/step
# 1/1 - 2s - loss: 0.1600 - mae: 0.3588 - 2s/epoch - 2s/step
# 1/1 - 0s - 137ms/epoch - 137ms/step
# 1/1 - 2s - loss: 10.9746 - mae: 1.0266 - 2s/epoch - 2s/step
# 1/1 - 0s - 173ms/epoch - 173ms/step
# 1/1 - 2s - loss: 1.5533 - mae: 0.3116 - 2s/epoch - 2s/step
# 1/1 - 0s - 140ms/epoch - 140ms/step
# 1/1 - 2s - loss: 0.2081 - mae: 0.3267 - 2s/epoch - 2s/step
# 1/1 - 0s - 198ms/epoch - 198ms/step
# 1/1 - 2s - loss: 21.1015 - mae: 0.5430 - 2s/epoch - 2s/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 2.8886 - mae: 0.6509 - 961ms/epoch - 961ms/step
# 1/1 - 0s - 119ms/epoch - 119ms/step
# 1/1 - 1s - loss: 0.5845 - mae: 0.6763 - 661ms/epoch - 661ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 21.2149 - mae: 0.5739 - 680ms/epoch - 680ms/step
# 1/1 - 0s - 136ms/epoch - 136ms/step
# 1/1 - 1s - loss: 3.6002 - mae: 0.9627 - 786ms/epoch - 786ms/step
# 1/1 - 0s - 111ms/epoch - 111ms/step
# 1/1 - 1s - loss: 0.0306 - mae: 0.1434 - 1s/epoch - 1s/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 9.8668 - mae: 0.1541 - 891ms/epoch - 891ms/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 2.1121 - mae: 0.7983 - 1s/epoch - 1s/step
# 1/1 - 0s - 144ms/epoch - 144ms/step
# 1/1 - 0s - loss: 0.2077 - mae: 0.4358 - 484ms/epoch - 484ms/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 9.9373 - mae: 0.1736 - 688ms/epoch - 688ms/step
# 1/1 - 0s - 93ms/epoch - 93ms/step
# 1/1 - 1s - loss: 2.0494 - mae: 0.7546 - 676ms/epoch - 676ms/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 0.7965 - mae: 0.8815 - 837ms/epoch - 837ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 21.4167 - mae: 0.7758 - 997ms/epoch - 997ms/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 1s - loss: 2.4609 - mae: 0.1268 - 964ms/epoch - 964ms/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 0.0223 - mae: 0.1388 - 604ms/epoch - 604ms/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 1s - loss: 21.3452 - mae: 0.8087 - 597ms/epoch - 597ms/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 2.8142 - mae: 0.6029 - 606ms/epoch - 606ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 2.5234 - mae: 1.5839 - 916ms/epoch - 916ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 9.8905 - mae: 0.1515 - 1s/epoch - 1s/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 2.4572 - mae: 0.9990 - 900ms/epoch - 900ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 1.0890 - mae: 1.0328 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 104ms/epoch - 104ms/step
# 1/1 - 1s - loss: 10.2212 - mae: 0.6654 - 636ms/epoch - 636ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 2.4992 - mae: 1.0259 - 640ms/epoch - 640ms/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 0.0506 - mae: 0.1719 - 864ms/epoch - 864ms/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 20.6830 - mae: 0.1608 - 973ms/epoch - 973ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 2.4914 - mae: 0.1624 - 977ms/epoch - 977ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 0.6116 - mae: 0.7696 - 686ms/epoch - 686ms/step
# 1/1 - 0s - 97ms/epoch - 97ms/step
# 1/1 - 1s - loss: 20.7771 - mae: 0.4507 - 611ms/epoch - 611ms/step
# 1/1 - 0s - 126ms/epoch - 126ms/step
# 1/1 - 1s - loss: 2.5786 - mae: 0.3400 - 620ms/epoch - 620ms/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 1.2026 - mae: 0.8601 - 1s/epoch - 1s/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 10.0902 - mae: 0.5545 - 1s/epoch - 1s/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 3.2307 - mae: 1.2607 - 1s/epoch - 1s/step
# 1/1 - 0s - 91ms/epoch - 91ms/step
# 1/1 - 1s - loss: 0.6831 - mae: 0.7736 - 1s/epoch - 1s/step
# 1/1 - 0s - 160ms/epoch - 160ms/step
# 1/1 - 1s - loss: 9.7990 - mae: 0.1899 - 700ms/epoch - 700ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 1.7076 - mae: 0.4762 - 656ms/epoch - 656ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 0.1341 - mae: 0.2853 - 1s/epoch - 1s/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 20.8507 - mae: 0.3748 - 965ms/epoch - 965ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 2.6234 - mae: 0.3977 - 971ms/epoch - 971ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 1.2894 - mae: 1.0789 - 1s/epoch - 1s/step
# 1/1 - 0s - 125ms/epoch - 125ms/step
# 1/1 - 1s - loss: 21.2509 - mae: 0.5837 - 824ms/epoch - 824ms/step
# 1/1 - 0s - 166ms/epoch - 166ms/step
# 1/1 - 1s - loss: 3.0280 - mae: 0.6302 - 581ms/epoch - 581ms/step
# 1/1 - 0s - 111ms/epoch - 111ms/step
# 1/1 - 1s - loss: 0.5284 - mae: 0.6480 - 1s/epoch - 1s/step
# 1/1 - 0s - 125ms/epoch - 125ms/step
# 1/1 - 1s - loss: 10.7905 - mae: 0.9375 - 1s/epoch - 1s/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 2.1539 - mae: 0.7447 - 1s/epoch - 1s/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 1s - loss: 3.3309e-04 - mae: 0.0176 - 596ms/epoch - 596ms/step
# 1/1 - 0s - 93ms/epoch - 93ms/step
# 1/1 - 1s - loss: 10.6783 - mae: 0.9045 - 882ms/epoch - 882ms/step
# 1/1 - 0s - 142ms/epoch - 142ms/step
# 1/1 - 1s - loss: 2.1340 - mae: 0.7683 - 666ms/epoch - 666ms/step
# 1/1 - 0s - 132ms/epoch - 132ms/step
# 1/1 - 1s - loss: 0.3554 - mae: 0.5350 - 1s/epoch - 1s/step
# 1/1 - 0s - 106ms/epoch - 106ms/step
# 1/1 - 1s - loss: 21.8434 - mae: 1.0507 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 2.8778 - mae: 0.5869 - 1s/epoch - 1s/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 0.2030 - mae: 0.3729 - 775ms/epoch - 775ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 21.9141 - mae: 0.8875 - 732ms/epoch - 732ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 4.1885 - mae: 1.1548 - 596ms/epoch - 596ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 20.7044 - mae: 0.2286 - 1s/epoch - 1s/step
# 2it [04:16, 128.10s/it]1/1 - 1s - loss: 0.0253 - mae: 0.1574 - 924ms/epoch - 924ms/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 9.9489 - mae: 0.2508 - 1s/epoch - 1s/step
# 1/1 - 0s - 103ms/epoch - 103ms/step
# 1/1 - 1s - loss: 1.4671 - mae: 0.1703 - 928ms/epoch - 928ms/step
# 1/1 - 0s - 95ms/epoch - 95ms/step
# 1/1 - 1s - loss: 0.0792 - mae: 0.1845 - 538ms/epoch - 538ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 9.8907 - mae: 0.2764 - 630ms/epoch - 630ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 1.5574 - mae: 0.2612 - 685ms/epoch - 685ms/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 0.1065 - mae: 0.2938 - 1s/epoch - 1s/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 20.5156 - mae: 0.1884 - 961ms/epoch - 961ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 2.4624 - mae: 0.1359 - 1s/epoch - 1s/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 0.1111 - mae: 0.3059 - 731ms/epoch - 731ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 20.7340 - mae: 0.1405 - 663ms/epoch - 663ms/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 2.4781 - mae: 0.1685 - 628ms/epoch - 628ms/step
# 1/1 - 0s - 127ms/epoch - 127ms/step
# 1/1 - 1s - loss: 0.0231 - mae: 0.1518 - 860ms/epoch - 860ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 9.8522 - mae: 0.1142 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 1.5138 - mae: 0.2503 - 999ms/epoch - 999ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 0.0372 - mae: 0.1676 - 958ms/epoch - 958ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 9.7486 - mae: 0.3377 - 715ms/epoch - 715ms/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 1.5477 - mae: 0.3445 - 573ms/epoch - 573ms/step
# 1/1 - 0s - 124ms/epoch - 124ms/step
# 1/1 - 1s - loss: 0.0323 - mae: 0.1388 - 943ms/epoch - 943ms/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 20.7054 - mae: 0.1097 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 2.4854 - mae: 0.1764 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 0.0185 - mae: 0.1210 - 671ms/epoch - 671ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 20.5349 - mae: 0.0851 - 566ms/epoch - 566ms/step
# 1/1 - 0s - 126ms/epoch - 126ms/step
# 1/1 - 1s - loss: 2.4873 - mae: 0.2058 - 727ms/epoch - 727ms/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 0.1680 - mae: 0.3493 - 1s/epoch - 1s/step
# 1/1 - 0s - 143ms/epoch - 143ms/step
# 1/1 - 1s - loss: 10.4350 - mae: 0.6196 - 1s/epoch - 1s/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 1.9002 - mae: 0.6048 - 1s/epoch - 1s/step
# 1/1 - 0s - 121ms/epoch - 121ms/step
# 1/1 - 1s - loss: 0.0872 - mae: 0.2241 - 665ms/epoch - 665ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 10.0214 - mae: 0.4856 - 644ms/epoch - 644ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 1.5529 - mae: 0.2769 - 772ms/epoch - 772ms/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 0.0143 - mae: 0.1026 - 993ms/epoch - 993ms/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 1s - loss: 20.6652 - mae: 0.1512 - 1s/epoch - 1s/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 2.8744 - mae: 0.4783 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 0.3865 - mae: 0.5400 - 598ms/epoch - 598ms/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 20.9947 - mae: 0.6584 - 1s/epoch - 1s/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 2.5764 - mae: 0.3002 - 685ms/epoch - 685ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 0.8457 - mae: 0.8070 - 1s/epoch - 1s/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 9.8925 - mae: 0.2901 - 1s/epoch - 1s/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 1s - loss: 1.4565 - mae: 0.1795 - 1s/epoch - 1s/step
# 1/1 - 0s - 124ms/epoch - 124ms/step
# 1/1 - 1s - loss: 2.0188 - mae: 1.1556 - 679ms/epoch - 679ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 10.4488 - mae: 0.8025 - 783ms/epoch - 783ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 1.7133 - mae: 0.5212 - 588ms/epoch - 588ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 0.0883 - mae: 0.2724 - 876ms/epoch - 876ms/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 21.0207 - mae: 0.4926 - 1s/epoch - 1s/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 2.6880 - mae: 0.4499 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 0.0773 - mae: 0.2454 - 721ms/epoch - 721ms/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 1s - loss: 21.1275 - mae: 0.7384 - 687ms/epoch - 687ms/step
# 1/1 - 0s - 127ms/epoch - 127ms/step
# 1/1 - 1s - loss: 2.5645 - mae: 0.3345 - 724ms/epoch - 724ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 0.1391 - mae: 0.3448 - 887ms/epoch - 887ms/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 1s - loss: 10.1080 - mae: 0.4683 - 1000ms/epoch - 1000ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 1.5380 - mae: 0.2560 - 964ms/epoch - 964ms/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 0.2031 - mae: 0.4277 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 9.7530 - mae: 0.1464 - 1s/epoch - 1s/step
# 1/1 - 0s - 195ms/epoch - 195ms/step
# 1/1 - 1s - loss: 1.7649 - mae: 0.5534 - 1s/epoch - 1s/step
# 1/1 - 0s - 155ms/epoch - 155ms/step
# 1/1 - 1s - loss: 0.1684 - mae: 0.3822 - 888ms/epoch - 888ms/step
# 1/1 - 0s - 60ms/epoch - 60ms/step
# 1/1 - 1s - loss: 21.2883 - mae: 0.7245 - 930ms/epoch - 930ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 3.1773 - mae: 0.8380 - 969ms/epoch - 969ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 0s - loss: 1.0049 - mae: 0.9921 - 488ms/epoch - 488ms/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 20.5268 - mae: 0.1404 - 539ms/epoch - 539ms/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 2.5548 - mae: 0.3252 - 563ms/epoch - 563ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 0.3543 - mae: 0.5786 - 975ms/epoch - 975ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 9.9281 - mae: 0.2045 - 1s/epoch - 1s/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 1.7960 - mae: 0.5976 - 1s/epoch - 1s/step
# 1/1 - 0s - 104ms/epoch - 104ms/step
# 1/1 - 1s - loss: 0.2734 - mae: 0.5026 - 550ms/epoch - 550ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 9.8463 - mae: 0.1706 - 697ms/epoch - 697ms/step
# 1/1 - 0s - 134ms/epoch - 134ms/step
# 1/1 - 1s - loss: 1.6895 - mae: 0.4797 - 569ms/epoch - 569ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 0.6542 - mae: 0.7957 - 976ms/epoch - 976ms/step
# 1/1 - 0s - 93ms/epoch - 93ms/step
# 1/1 - 1s - loss: 20.9134 - mae: 0.5775 - 1s/epoch - 1s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 2.5199 - mae: 0.2688 - 912ms/epoch - 912ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 0.3890 - mae: 0.6080 - 638ms/epoch - 638ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 20.6271 - mae: 0.2057 - 717ms/epoch - 717ms/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 2.5746 - mae: 0.3275 - 655ms/epoch - 655ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 0.9539 - mae: 0.8986 - 1s/epoch - 1s/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 10.1421 - mae: 0.4104 - 1s/epoch - 1s/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 2.2957 - mae: 0.7150 - 1s/epoch - 1s/step
# 1/1 - 0s - 109ms/epoch - 109ms/step
# 1/1 - 1s - loss: 1.5410 - mae: 1.0834 - 647ms/epoch - 647ms/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 9.8639 - mae: 0.1118 - 831ms/epoch - 831ms/step
# 1/1 - 0s - 125ms/epoch - 125ms/step
# 1/1 - 1s - loss: 1.5731 - mae: 0.2860 - 717ms/epoch - 717ms/step
# 1/1 - 0s - 93ms/epoch - 93ms/step
# 1/1 - 1s - loss: 1.6841 - mae: 1.1876 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 21.6436 - mae: 0.8458 - 1s/epoch - 1s/step
# 1/1 - 0s - 119ms/epoch - 119ms/step
# 1/1 - 2s - loss: 2.8094 - mae: 0.5257 - 2s/epoch - 2s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 2s - loss: 0.3474 - mae: 0.4961 - 2s/epoch - 2s/step
# 1/1 - 0s - 264ms/epoch - 264ms/step
# 1/1 - 2s - loss: 21.4305 - mae: 0.7956 - 2s/epoch - 2s/step
# 1/1 - 0s - 230ms/epoch - 230ms/step
# 1/1 - 2s - loss: 3.3136 - mae: 0.7861 - 2s/epoch - 2s/step
# 1/1 - 0s - 302ms/epoch - 302ms/step
# 1/1 - 2s - loss: 0.7213 - mae: 0.7478 - 2s/epoch - 2s/step
# 1/1 - 0s - 232ms/epoch - 232ms/step
# 1/1 - 3s - loss: 9.8837 - mae: 0.1541 - 3s/epoch - 3s/step
# 1/1 - 0s - 195ms/epoch - 195ms/step
# 1/1 - 3s - loss: 4.9613 - mae: 1.5362 - 3s/epoch - 3s/step
# 1/1 - 0s - 174ms/epoch - 174ms/step
# 1/1 - 2s - loss: 0.7843 - mae: 0.6394 - 2s/epoch - 2s/step
# 1/1 - 0s - 203ms/epoch - 203ms/step
# 1/1 - 2s - loss: 10.7959 - mae: 0.9696 - 2s/epoch - 2s/step
# 1/1 - 0s - 206ms/epoch - 206ms/step
# 1/1 - 2s - loss: 2.1381 - mae: 0.7223 - 2s/epoch - 2s/step
# 1/1 - 0s - 149ms/epoch - 149ms/step
# 1/1 - 3s - loss: 2.7196 - mae: 1.1440 - 3s/epoch - 3s/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 3s - loss: 21.3157 - mae: 0.7430 - 3s/epoch - 3s/step
# 1/1 - 0s - 226ms/epoch - 226ms/step
# 1/1 - 3s - loss: 3.1733 - mae: 0.8193 - 3s/epoch - 3s/step
# 1/1 - 0s - 137ms/epoch - 137ms/step
# 1/1 - 1s - loss: 1.9155 - mae: 1.3615 - 1s/epoch - 1s/step
# 1/1 - 0s - 152ms/epoch - 152ms/step
# 1/1 - 2s - loss: 20.7581 - mae: 0.3623 - 2s/epoch - 2s/step
# 1/1 - 0s - 235ms/epoch - 235ms/step
# 1/1 - 1s - loss: 2.6412 - mae: 0.4099 - 634ms/epoch - 634ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 0.1185 - mae: 0.3019 - 1s/epoch - 1s/step
# 3it [06:43, 136.49s/it]1/1 - 1s - loss: 0.1381 - mae: 0.3317 - 970ms/epoch - 970ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 10.1130 - mae: 0.4537 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 1.4507 - mae: 0.1182 - 1s/epoch - 1s/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 0s - loss: 1.6055 - mae: 0.8298 - 482ms/epoch - 482ms/step
# 1/1 - 0s - 137ms/epoch - 137ms/step
# 1/1 - 1s - loss: 9.7721 - mae: 0.2327 - 569ms/epoch - 569ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 1.6530 - mae: 0.3925 - 662ms/epoch - 662ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 0.4691 - mae: 0.5633 - 1s/epoch - 1s/step
# 1/1 - 0s - 105ms/epoch - 105ms/step
# 1/1 - 1s - loss: 20.7259 - mae: 0.2392 - 1s/epoch - 1s/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 2s - loss: 3.2129 - mae: 0.7678 - 2s/epoch - 2s/step
# 1/1 - 0s - 60ms/epoch - 60ms/step
# 1/1 - 1s - loss: 0.1455 - mae: 0.3657 - 784ms/epoch - 784ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 20.8481 - mae: 0.3432 - 672ms/epoch - 672ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 2.5722 - mae: 0.3113 - 687ms/epoch - 687ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 0.1201 - mae: 0.3102 - 893ms/epoch - 893ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 9.8996 - mae: 0.3202 - 1s/epoch - 1s/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 1.5500 - mae: 0.2544 - 1s/epoch - 1s/step
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 0s - loss: 0.2268 - mae: 0.4145 - 489ms/epoch - 489ms/step
# 1/1 - 0s - 59ms/epoch - 59ms/step
# 1/1 - 1s - loss: 9.9753 - mae: 0.2497 - 628ms/epoch - 628ms/step
# 1/1 - 0s - 106ms/epoch - 106ms/step
# 1/1 - 1s - loss: 1.6864 - mae: 0.4474 - 621ms/epoch - 621ms/step
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 1s - loss: 0.7733 - mae: 0.6278 - 949ms/epoch - 949ms/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 20.5389 - mae: 0.2041 - 919ms/epoch - 919ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 2.5863 - mae: 0.3385 - 1s/epoch - 1s/step
# 1/1 - 0s - 161ms/epoch - 161ms/step
# 1/1 - 1s - loss: 2.1255 - mae: 1.0692 - 541ms/epoch - 541ms/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 20.9230 - mae: 0.3840 - 659ms/epoch - 659ms/step
# 1/1 - 0s - 122ms/epoch - 122ms/step
# 1/1 - 1s - loss: 2.5458 - mae: 0.2557 - 740ms/epoch - 740ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 32.3364 - mae: 3.6620 - 1s/epoch - 1s/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 10.5298 - mae: 0.6596 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 2.9165 - mae: 0.8039 - 1s/epoch - 1s/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 4.1572 - mae: 1.7332 - 614ms/epoch - 614ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 9.8269 - mae: 0.2018 - 773ms/epoch - 773ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 1.8365 - mae: 0.5312 - 1000ms/epoch - 1000ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 0.0571 - mae: 0.2134 - 1s/epoch - 1s/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 22.3542 - mae: 0.8204 - 968ms/epoch - 968ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 4.6421 - mae: 1.0082 - 1s/epoch - 1s/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 1.5970 - mae: 1.0557 - 686ms/epoch - 686ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 21.8874 - mae: 1.0762 - 1s/epoch - 1s/step
# 1/1 - 0s - 135ms/epoch - 135ms/step
# 1/1 - 1s - loss: 10.0579 - mae: 1.7589 - 826ms/epoch - 826ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 0.6149 - mae: 0.6522 - 991ms/epoch - 991ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 14.7158 - mae: 1.5034 - 1s/epoch - 1s/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 1.4548 - mae: 0.1458 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 7.9554 - mae: 1.8346 - 690ms/epoch - 690ms/step
# 1/1 - 0s - 131ms/epoch - 131ms/step
# 1/1 - 1s - loss: 10.2138 - mae: 0.5244 - 763ms/epoch - 763ms/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 6.1324 - mae: 1.4575 - 724ms/epoch - 724ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 0.6040 - mae: 0.6336 - 1s/epoch - 1s/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 21.8056 - mae: 0.9812 - 1s/epoch - 1s/step
# 1/1 - 0s - 153ms/epoch - 153ms/step
# 1/1 - 1s - loss: 5.6264 - mae: 1.3380 - 1s/epoch - 1s/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 0.5049 - mae: 0.6421 - 588ms/epoch - 588ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 28.0023 - mae: 1.9259 - 1s/epoch - 1s/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 7.5393 - mae: 1.5545 - 712ms/epoch - 712ms/step
# 1/1 - 0s - 170ms/epoch - 170ms/step
# 1/1 - 1s - loss: 0.2000 - mae: 0.4207 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 10.0042 - mae: 0.3645 - 1s/epoch - 1s/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 3.6599 - mae: 1.4767 - 1s/epoch - 1s/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 0.5065 - mae: 0.6940 - 655ms/epoch - 655ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 9.7951 - mae: 0.1596 - 817ms/epoch - 817ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 2.2173 - mae: 0.8700 - 608ms/epoch - 608ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 1.8093 - mae: 1.3355 - 966ms/epoch - 966ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 21.6630 - mae: 1.0148 - 1s/epoch - 1s/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 3s - loss: 2.6583 - mae: 0.4399 - 3s/epoch - 3s/step
# 1/1 - 0s - 217ms/epoch - 217ms/step
# 1/1 - 2s - loss: 0.5009 - mae: 0.6900 - 2s/epoch - 2s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 21.3384 - mae: 0.8777 - 1s/epoch - 1s/step
# 1/1 - 0s - 222ms/epoch - 222ms/step
# 1/1 - 2s - loss: 2.4609 - mae: 0.1132 - 2s/epoch - 2s/step
# 1/1 - 0s - 179ms/epoch - 179ms/step
# 1/1 - 2s - loss: 0.0371 - mae: 0.1168 - 2s/epoch - 2s/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 9.8685 - mae: 0.3518 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 1.4776 - mae: 0.1521 - 981ms/epoch - 981ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 0.7031 - mae: 0.8222 - 878ms/epoch - 878ms/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 10.6996 - mae: 0.9671 - 770ms/epoch - 770ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 1.6002 - mae: 0.3647 - 705ms/epoch - 705ms/step
# 1/1 - 0s - 94ms/epoch - 94ms/step
# 1/1 - 1s - loss: 2.2456 - mae: 1.4900 - 914ms/epoch - 914ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 20.5986 - mae: 0.1967 - 1s/epoch - 1s/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 1s - loss: 2.4752 - mae: 0.1553 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 0.2651 - mae: 0.4876 - 611ms/epoch - 611ms/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 20.7496 - mae: 0.2954 - 737ms/epoch - 737ms/step
# 1/1 - 0s - 98ms/epoch - 98ms/step
# 1/1 - 1s - loss: 4.8329 - mae: 1.5336 - 601ms/epoch - 601ms/step
# 1/1 - 0s - 124ms/epoch - 124ms/step
# 1/1 - 1s - loss: 2.0991 - mae: 1.1239 - 954ms/epoch - 954ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 2s - loss: 11.0279 - mae: 0.9924 - 2s/epoch - 2s/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 2.1796 - mae: 0.6429 - 1s/epoch - 1s/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 1.4589 - mae: 1.1015 - 798ms/epoch - 798ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 10.5229 - mae: 0.8067 - 736ms/epoch - 736ms/step
# 1/1 - 0s - 136ms/epoch - 136ms/step
# 1/1 - 1s - loss: 2.4771 - mae: 0.8644 - 749ms/epoch - 749ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 0.7963 - mae: 0.7710 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 21.5469 - mae: 0.8077 - 1s/epoch - 1s/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 3.7105 - mae: 0.8536 - 1s/epoch - 1s/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 0.5608 - mae: 0.5750 - 709ms/epoch - 709ms/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 21.4531 - mae: 0.7964 - 871ms/epoch - 871ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 3.0371 - mae: 0.7586 - 766ms/epoch - 766ms/step
# 1/1 - 0s - 98ms/epoch - 98ms/step
# 1/1 - 1s - loss: 0.0983 - mae: 0.2477 - 944ms/epoch - 944ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 2s - loss: 10.4651 - mae: 0.7450 - 2s/epoch - 2s/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 1s - loss: 2.3803 - mae: 0.6956 - 1s/epoch - 1s/step
# 1/1 - 0s - 106ms/epoch - 106ms/step
# 1/1 - 1s - loss: 0.7025 - mae: 0.6727 - 706ms/epoch - 706ms/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 13.1739 - mae: 1.6877 - 967ms/epoch - 967ms/step
# 1/1 - 0s - 103ms/epoch - 103ms/step
# 1/1 - 1s - loss: 3.2299 - mae: 1.2257 - 757ms/epoch - 757ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 0.2252 - mae: 0.3747 - 1s/epoch - 1s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 2s - loss: 21.8999 - mae: 0.9973 - 2s/epoch - 2s/step
# 1/1 - 0s - 168ms/epoch - 168ms/step
# 1/1 - 3s - loss: 4.9471 - mae: 1.4776 - 3s/epoch - 3s/step
# 1/1 - 0s - 141ms/epoch - 141ms/step
# 1/1 - 2s - loss: 1.7128 - mae: 1.1960 - 2s/epoch - 2s/step
# 1/1 - 0s - 141ms/epoch - 141ms/step
# 1/1 - 1s - loss: 20.9723 - mae: 0.5084 - 943ms/epoch - 943ms/step
# 1/1 - 0s - 106ms/epoch - 106ms/step
# 1/1 - 1s - loss: 3.1358 - mae: 0.7533 - 678ms/epoch - 678ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 10.4702 - mae: 0.5434 - 730ms/epoch - 730ms/step
# 4it [08:55, 135.01s/it]1/1 - 1s - loss: 0.1168 - mae: 0.2984 - 836ms/epoch - 836ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 9.9723 - mae: 0.3443 - 1s/epoch - 1s/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 1.5310 - mae: 0.2929 - 1s/epoch - 1s/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 0.2474 - mae: 0.3684 - 784ms/epoch - 784ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 9.7950 - mae: 0.1567 - 735ms/epoch - 735ms/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 1.5187 - mae: 0.1992 - 673ms/epoch - 673ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 0.1052 - mae: 0.2983 - 956ms/epoch - 956ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 20.6920 - mae: 0.2179 - 1s/epoch - 1s/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 2.5598 - mae: 0.2813 - 964ms/epoch - 964ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 0.0108 - mae: 0.1036 - 545ms/epoch - 545ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 20.7254 - mae: 0.1995 - 604ms/epoch - 604ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 2.4821 - mae: 0.1979 - 698ms/epoch - 698ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 0.0767 - mae: 0.2374 - 1s/epoch - 1s/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 9.9185 - mae: 0.3275 - 1s/epoch - 1s/step
# 1/1 - 0s - 101ms/epoch - 101ms/step
# 1/1 - 1s - loss: 1.4985 - mae: 0.2614 - 1s/epoch - 1s/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 0.0878 - mae: 0.2049 - 569ms/epoch - 569ms/step
# 1/1 - 0s - 96ms/epoch - 96ms/step
# 1/1 - 1s - loss: 9.8978 - mae: 0.2500 - 607ms/epoch - 607ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 1.5667 - mae: 0.3130 - 668ms/epoch - 668ms/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 0.0698 - mae: 0.1982 - 901ms/epoch - 901ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 20.5842 - mae: 0.3086 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 2.5228 - mae: 0.2481 - 1s/epoch - 1s/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 0.0716 - mae: 0.2520 - 624ms/epoch - 624ms/step
# 1/1 - 0s - 119ms/epoch - 119ms/step
# 1/1 - 1s - loss: 20.6609 - mae: 0.2165 - 690ms/epoch - 690ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 2.4912 - mae: 0.2144 - 693ms/epoch - 693ms/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 0.3566 - mae: 0.5299 - 1s/epoch - 1s/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 10.2034 - mae: 0.5378 - 1s/epoch - 1s/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 2.2902 - mae: 0.7139 - 1s/epoch - 1s/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 0.1205 - mae: 0.3387 - 718ms/epoch - 718ms/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 1s - loss: 10.0525 - mae: 0.4899 - 743ms/epoch - 743ms/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 1s - loss: 1.7064 - mae: 0.4037 - 671ms/epoch - 671ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 0.2723 - mae: 0.4142 - 1s/epoch - 1s/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 20.6873 - mae: 0.3973 - 1s/epoch - 1s/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 2.6649 - mae: 0.3264 - 1s/epoch - 1s/step
# 1/1 - 0s - 71ms/epoch - 71ms/step
# 1/1 - 1s - loss: 0.1779 - mae: 0.3993 - 686ms/epoch - 686ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 21.1738 - mae: 0.5935 - 756ms/epoch - 756ms/step
# 1/1 - 0s - 107ms/epoch - 107ms/step
# 1/1 - 1s - loss: 2.9395 - mae: 0.6535 - 829ms/epoch - 829ms/step
# 1/1 - 0s - 102ms/epoch - 102ms/step
# 1/1 - 1s - loss: 0.4326 - mae: 0.5739 - 1s/epoch - 1s/step
# 1/1 - 0s - 127ms/epoch - 127ms/step
# 1/1 - 1s - loss: 9.8195 - mae: 0.0682 - 1s/epoch - 1s/step
# 1/1 - 0s - 102ms/epoch - 102ms/step
# 1/1 - 1s - loss: 1.6619 - mae: 0.3685 - 1s/epoch - 1s/step
# 1/1 - 0s - 184ms/epoch - 184ms/step
# 1/1 - 1s - loss: 1.7170 - mae: 1.2648 - 843ms/epoch - 843ms/step
# 1/1 - 0s - 95ms/epoch - 95ms/step
# 1/1 - 1s - loss: 9.8643 - mae: 0.2478 - 1s/epoch - 1s/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 2s - loss: 1.4528 - mae: 0.2238 - 2s/epoch - 2s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 0.4785 - mae: 0.6406 - 1s/epoch - 1s/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 20.7491 - mae: 0.2216 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 3.0286 - mae: 0.5337 - 1s/epoch - 1s/step
# 1/1 - 0s - 97ms/epoch - 97ms/step
# 1/1 - 1s - loss: 0.3670 - mae: 0.4934 - 709ms/epoch - 709ms/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 20.5931 - mae: 0.3813 - 890ms/epoch - 890ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 4.1628 - mae: 1.0264 - 807ms/epoch - 807ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 0.8105 - mae: 0.8741 - 839ms/epoch - 839ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 9.8583 - mae: 0.2135 - 1s/epoch - 1s/step
# 1/1 - 0s - 59ms/epoch - 59ms/step
# 1/1 - 2s - loss: 1.5093 - mae: 0.2024 - 2s/epoch - 2s/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 0.7047 - mae: 0.8103 - 531ms/epoch - 531ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 9.7614 - mae: 0.1925 - 775ms/epoch - 775ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 1.5907 - mae: 0.3362 - 646ms/epoch - 646ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 0.0934 - mae: 0.2624 - 1s/epoch - 1s/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 20.8123 - mae: 0.5120 - 1s/epoch - 1s/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 3.4456 - mae: 0.9866 - 1s/epoch - 1s/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 0.2558 - mae: 0.4575 - 685ms/epoch - 685ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 23.7917 - mae: 1.7934 - 520ms/epoch - 520ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 2.7922 - mae: 0.5435 - 804ms/epoch - 804ms/step
# 1/1 - 0s - 146ms/epoch - 146ms/step
# 1/1 - 1s - loss: 0.8648 - mae: 0.9045 - 868ms/epoch - 868ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 10.9399 - mae: 1.0790 - 1s/epoch - 1s/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 2.4250 - mae: 0.9794 - 912ms/epoch - 912ms/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 0.3874 - mae: 0.5815 - 692ms/epoch - 692ms/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 10.0520 - mae: 0.4277 - 562ms/epoch - 562ms/step
# 1/1 - 0s - 106ms/epoch - 106ms/step
# 1/1 - 1s - loss: 2.4875 - mae: 1.0013 - 724ms/epoch - 724ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 0.2022 - mae: 0.3946 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 20.8910 - mae: 0.3166 - 1s/epoch - 1s/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 3.0668 - mae: 0.7793 - 959ms/epoch - 959ms/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 2.2500 - mae: 1.4842 - 524ms/epoch - 524ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 20.7471 - mae: 0.1812 - 635ms/epoch - 635ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 4.2930 - mae: 1.3433 - 592ms/epoch - 592ms/step
# 1/1 - 0s - 110ms/epoch - 110ms/step
# 1/1 - 1s - loss: 1.1893 - mae: 0.9247 - 1s/epoch - 1s/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 12.8973 - mae: 1.5004 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 2.0381 - mae: 0.6482 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 1.3603 - mae: 0.9555 - 665ms/epoch - 665ms/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# ...
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 1s - loss: 4.3757 - mae: 1.4387 - 1s/epoch - 1s/step
# 1/1 - 0s - 110ms/epoch - 110ms/step
# 1/1 - 1s - loss: 20.5945 - mae: 0.2615 - 1s/epoch - 1s/step
# 1/1 - 0s - 120ms/epoch - 120ms/step
# 1/1 - 2s - loss: 13.0900 - mae: 2.7622 - 2s/epoch - 2s/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 1.4172 - mae: 0.8612 - 703ms/epoch - 703ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 24.2956 - mae: 1.5262 - 774ms/epoch - 774ms/step
# 1/1 - 0s - 136ms/epoch - 136ms/step
# 1/1 - 1s - loss: 4.9253 - mae: 1.2156 - 835ms/epoch - 835ms/step
# 1/1 - 0s - 152ms/epoch - 152ms/step
# 1/1 - 1s - loss: 3.4107 - mae: 1.6839 - 1s/epoch - 1s/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 1s - loss: 10.0481 - mae: 0.3381 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 21.4659 - mae: 3.2669 - 1s/epoch - 1s/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 1.4335 - mae: 0.8933 - 819ms/epoch - 819ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 10.2837 - mae: 0.4978 - 633ms/epoch - 633ms/step
# 1/1 - 0s - 109ms/epoch - 109ms/step
# 1/1 - 1s - loss: 9.4565 - mae: 1.9802 - 714ms/epoch - 714ms/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 5.6051 - mae: 1.8304 - 1s/epoch - 1s/step
# 1/1 - 0s - 127ms/epoch - 127ms/step
# 1/1 - 1s - loss: 26.6917 - mae: 1.6716 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 15.5989 - mae: 2.3748 - 1s/epoch - 1s/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 26.4552 - mae: 3.9245 - 1s/epoch - 1s/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 32.3665 - mae: 2.8753 - 908ms/epoch - 908ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 10.6484 - mae: 2.7084 - 994ms/epoch - 994ms/step
# 1/1 - 0s - 99ms/epoch - 99ms/step
# 1/1 - 1s - loss: 0.3126 - mae: 0.5192 - 1s/epoch - 1s/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 9.8746 - mae: 0.4658 - 1s/epoch - 1s/step
# 1/1 - 0s - 59ms/epoch - 59ms/step
# 1/1 - 1s - loss: 1.6031 - mae: 0.3804 - 983ms/epoch - 983ms/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 0.4212 - mae: 0.6285 - 553ms/epoch - 553ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 13.5781 - mae: 1.9326 - 834ms/epoch - 834ms/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 1.5607 - mae: 0.3437 - 759ms/epoch - 759ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 2.0349 - mae: 1.4156 - 863ms/epoch - 863ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 20.5867 - mae: 0.1566 - 1s/epoch - 1s/step
# 1/1 - 0s - 126ms/epoch - 126ms/step
# 1/1 - 1s - loss: 3.3499 - mae: 0.9425 - 975ms/epoch - 975ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 0.0223 - mae: 0.1309 - 575ms/epoch - 575ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 20.6084 - mae: 0.1936 - 891ms/epoch - 891ms/step
# 1/1 - 0s - 61ms/epoch - 61ms/step
# 1/1 - 1s - loss: 2.5026 - mae: 0.1929 - 765ms/epoch - 765ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 0.6618 - mae: 0.7945 - 1s/epoch - 1s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 11.2031 - mae: 1.1785 - 925ms/epoch - 925ms/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 1.8484 - mae: 0.6244 - 974ms/epoch - 974ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 0.1258 - mae: 0.3189 - 556ms/epoch - 556ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 9.8862 - mae: 0.2339 - 575ms/epoch - 575ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 1.4642 - mae: 0.1470 - 650ms/epoch - 650ms/step
# 1/1 - 0s - 61ms/epoch - 61ms/step
# 1/1 - 1s - loss: 0.1214 - mae: 0.3128 - 850ms/epoch - 850ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 20.4596 - mae: 0.2606 - 1s/epoch - 1s/step
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 1s - loss: 3.2264 - mae: 0.8730 - 857ms/epoch - 857ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 0.1558 - mae: 0.3547 - 537ms/epoch - 537ms/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 20.7249 - mae: 0.1933 - 753ms/epoch - 753ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 3.5889 - mae: 1.0617 - 601ms/epoch - 601ms/step
# 1/1 - 0s - 95ms/epoch - 95ms/step
# 1/1 - 1s - loss: 1.5263 - mae: 0.7784 - 1s/epoch - 1s/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 10.6371 - mae: 0.7690 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 2s - loss: 7.6043 - mae: 2.3434 - 2s/epoch - 2s/step
# 1/1 - 0s - 103ms/epoch - 103ms/step
# 1/1 - 1s - loss: 0.8317 - mae: 0.8086 - 691ms/epoch - 691ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 10.9001 - mae: 1.0291 - 968ms/epoch - 968ms/step
# 1/1 - 0s - 83ms/epoch - 83ms/step
# 1/1 - 1s - loss: 5.6606 - mae: 1.8417 - 746ms/epoch - 746ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 0.4758 - mae: 0.5782 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 22.6466 - mae: 1.3723 - 1s/epoch - 1s/step
# 1/1 - 0s - 119ms/epoch - 119ms/step
# 1/1 - 1s - loss: 3.7193 - mae: 0.9075 - 1s/epoch - 1s/step
# 1/1 - 0s - 111ms/epoch - 111ms/step
# 1/1 - 1s - loss: 0.3649 - mae: 0.5942 - 733ms/epoch - 733ms/step
# 1/1 - 0s - 72ms/epoch - 72ms/step
# 1/1 - 1s - loss: 23.9854 - mae: 1.7964 - 716ms/epoch - 716ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 2.5796 - mae: 0.2634 - 1s/epoch - 1s/step
# 1/1 - 0s - 95ms/epoch - 95ms/step
# 1/1 - 1s - loss: 0.8232 - mae: 0.7719 - 1s/epoch - 1s/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 11.3171 - mae: 1.0203 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 3.4041 - mae: 1.3845 - 1s/epoch - 1s/step
# 1/1 - 0s - 64ms/epoch - 64ms/step
# 1/1 - 1s - loss: 0.7278 - mae: 0.8340 - 1s/epoch - 1s/step
# 1/1 - 0s - 108ms/epoch - 108ms/step
# 1/1 - 1s - loss: 11.7164 - mae: 1.2607 - 848ms/epoch - 848ms/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 1.7835 - mae: 0.5473 - 872ms/epoch - 872ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 1.4258 - mae: 1.1121 - 885ms/epoch - 885ms/step
# 1/1 - 0s - 198ms/epoch - 198ms/step
# 1/1 - 1s - loss: 21.9818 - mae: 0.9979 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 5.7879 - mae: 1.7955 - 1s/epoch - 1s/step
# 1/1 - 0s - 150ms/epoch - 150ms/step
# 1/1 - 1s - loss: 1.8698 - mae: 1.2156 - 732ms/epoch - 732ms/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 20.7075 - mae: 0.2380 - 737ms/epoch - 737ms/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 3.4232 - mae: 0.7487 - 806ms/epoch - 806ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 0.9480 - mae: 0.9001 - 651ms/epoch - 651ms/step
# 8it [17:06, 125.25s/it]1/1 - 1s - loss: 0.6459 - mae: 0.7185 - 1s/epoch - 1s/step
# 1/1 - 0s - 108ms/epoch - 108ms/step
# 1/1 - 1s - loss: 10.2540 - mae: 0.5805 - 971ms/epoch - 971ms/step
# 1/1 - 0s - 63ms/epoch - 63ms/step
# 1/1 - 1s - loss: 2.5477 - mae: 1.0296 - 975ms/epoch - 975ms/step
# 1/1 - 0s - 127ms/epoch - 127ms/step
# 1/1 - 1s - loss: 5.2859 - mae: 2.1868 - 590ms/epoch - 590ms/step
# 1/1 - 0s - 118ms/epoch - 118ms/step
# 1/1 - 1s - loss: 11.8615 - mae: 1.2968 - 622ms/epoch - 622ms/step
# 1/1 - 0s - 66ms/epoch - 66ms/step
# 1/1 - 1s - loss: 1.9706 - mae: 0.6032 - 690ms/epoch - 690ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 0.3654 - mae: 0.5158 - 1s/epoch - 1s/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 21.1872 - mae: 0.6328 - 1s/epoch - 1s/step
# 1/1 - 0s - 129ms/epoch - 129ms/step
# 1/1 - 1s - loss: 3.9219 - mae: 0.9362 - 1s/epoch - 1s/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 2.7638 - mae: 1.5946 - 575ms/epoch - 575ms/step
# 1/1 - 0s - 108ms/epoch - 108ms/step
# 1/1 - 1s - loss: 21.0716 - mae: 0.7066 - 692ms/epoch - 692ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 2.8886 - mae: 0.6735 - 717ms/epoch - 717ms/step
# 1/1 - 0s - 121ms/epoch - 121ms/step
# 1/1 - 1s - loss: 0.6156 - mae: 0.7568 - 867ms/epoch - 867ms/step
# 1/1 - 0s - 61ms/epoch - 61ms/step
# 1/1 - 1s - loss: 9.8791 - mae: 0.2202 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 2.0628 - mae: 0.6237 - 1s/epoch - 1s/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 1.2634 - mae: 0.9529 - 1s/epoch - 1s/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 10.3266 - mae: 0.6501 - 701ms/epoch - 701ms/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 1.6348 - mae: 0.4137 - 1s/epoch - 1s/step
# 1/1 - 0s - 149ms/epoch - 149ms/step
# 1/1 - 2s - loss: 0.3047 - mae: 0.4403 - 2s/epoch - 2s/step
# 1/1 - 0s - 181ms/epoch - 181ms/step
# 1/1 - 2s - loss: 20.9603 - mae: 0.5953 - 2s/epoch - 2s/step
# 1/1 - 0s - 160ms/epoch - 160ms/step
# 1/1 - 2s - loss: 2.5934 - mae: 0.3452 - 2s/epoch - 2s/step
# 1/1 - 0s - 231ms/epoch - 231ms/step
# 1/1 - 1s - loss: 0.1395 - mae: 0.2939 - 1s/epoch - 1s/step
# 1/1 - 0s - 198ms/epoch - 198ms/step
# 1/1 - 1s - loss: 20.7077 - mae: 0.3379 - 1s/epoch - 1s/step
# 1/1 - 0s - 127ms/epoch - 127ms/step
# 1/1 - 1s - loss: 2.6585 - mae: 0.3642 - 1s/epoch - 1s/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 17.1118 - mae: 2.7214 - 962ms/epoch - 962ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 10.4856 - mae: 0.7457 - 1s/epoch - 1s/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 3.2744 - mae: 1.3455 - 990ms/epoch - 990ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 2.5872 - mae: 1.3919 - 576ms/epoch - 576ms/step
# 1/1 - 0s - 124ms/epoch - 124ms/step
# 1/1 - 1s - loss: 9.8737 - mae: 0.1359 - 664ms/epoch - 664ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 18.2791 - mae: 2.8200 - 700ms/epoch - 700ms/step
# 1/1 - 0s - 84ms/epoch - 84ms/step
# 1/1 - 1s - loss: 10.6215 - mae: 2.8751 - 1s/epoch - 1s/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 2s - loss: 22.1949 - mae: 1.1092 - 2s/epoch - 2s/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 10.2971 - mae: 2.6936 - 1s/epoch - 1s/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 3.8328 - mae: 1.6776 - 707ms/epoch - 707ms/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 1s - loss: 23.2137 - mae: 1.3224 - 800ms/epoch - 800ms/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 4.6173 - mae: 1.3600 - 664ms/epoch - 664ms/step
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 1s - loss: 1.0810 - mae: 0.7740 - 1s/epoch - 1s/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 23.2712 - mae: 3.0489 - 1s/epoch - 1s/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 4.1014 - mae: 1.2500 - 1s/epoch - 1s/step
# 1/1 - 0s - 91ms/epoch - 91ms/step
# 1/1 - 1s - loss: 3.3070 - mae: 1.4002 - 762ms/epoch - 762ms/step
# 1/1 - 0s - 75ms/epoch - 75ms/step
# 1/1 - 1s - loss: 18.8062 - mae: 2.5544 - 835ms/epoch - 835ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 5.8093 - mae: 1.6783 - 779ms/epoch - 779ms/step
# 1/1 - 0s - 85ms/epoch - 85ms/step
# 1/1 - 1s - loss: 6.5560 - mae: 1.8637 - 1s/epoch - 1s/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 40.8136 - mae: 3.6685 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 2s - loss: 4.4423 - mae: 1.2357 - 2s/epoch - 2s/step
# 1/1 - 0s - 86ms/epoch - 86ms/step
# 1/1 - 1s - loss: 4.0632 - mae: 1.8843 - 694ms/epoch - 694ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 33.0195 - mae: 3.1017 - 722ms/epoch - 722ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 27.2890 - mae: 4.6672 - 729ms/epoch - 729ms/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 1.0775 - mae: 1.0268 - 1s/epoch - 1s/step
# 1/1 - 0s - 69ms/epoch - 69ms/step
# 1/1 - 1s - loss: 10.3422 - mae: 0.7128 - 1s/epoch - 1s/step
# 1/1 - 0s - 104ms/epoch - 104ms/step
# 1/1 - 1s - loss: 1.8076 - mae: 0.5724 - 941ms/epoch - 941ms/step
# 1/1 - 0s - 89ms/epoch - 89ms/step
# 1/1 - 1s - loss: 0.0498 - mae: 0.1937 - 549ms/epoch - 549ms/step
# 1/1 - 0s - 77ms/epoch - 77ms/step
# 1/1 - 1s - loss: 9.9597 - mae: 0.3879 - 620ms/epoch - 620ms/step
# 1/1 - 0s - 101ms/epoch - 101ms/step
# 1/1 - 1s - loss: 1.5020 - mae: 0.1838 - 618ms/epoch - 618ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 0.1782 - mae: 0.3926 - 1s/epoch - 1s/step
# 1/1 - 0s - 79ms/epoch - 79ms/step
# 1/1 - 1s - loss: 20.6949 - mae: 0.1559 - 1s/epoch - 1s/step
# 1/1 - 0s - 74ms/epoch - 74ms/step
# 1/1 - 1s - loss: 2.6283 - mae: 0.3870 - 872ms/epoch - 872ms/step
# 1/1 - 0s - 110ms/epoch - 110ms/step
# 1/1 - 1s - loss: 0.0669 - mae: 0.1999 - 721ms/epoch - 721ms/step
# 1/1 - 0s - 68ms/epoch - 68ms/step
# 1/1 - 1s - loss: 20.6044 - mae: 0.1318 - 872ms/epoch - 872ms/step
# 1/1 - 0s - 100ms/epoch - 100ms/step
# 1/1 - 1s - loss: 2.4666 - mae: 0.1996 - 1s/epoch - 1s/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 0.6064 - mae: 0.7606 - 1s/epoch - 1s/step
# 1/1 - 0s - 114ms/epoch - 114ms/step
# 1/1 - 1s - loss: 9.9042 - mae: 0.2358 - 889ms/epoch - 889ms/step
# 1/1 - 0s - 123ms/epoch - 123ms/step
# 1/1 - 1s - loss: 2.2054 - mae: 0.8488 - 1s/epoch - 1s/step
# 1/1 - 0s - 70ms/epoch - 70ms/step
# 1/1 - 1s - loss: 0.1535 - mae: 0.3570 - 541ms/epoch - 541ms/step
# 1/1 - 0s - 91ms/epoch - 91ms/step
# 1/1 - 1s - loss: 10.2936 - mae: 0.5869 - 608ms/epoch - 608ms/step
# 1/1 - 0s - 116ms/epoch - 116ms/step
# 1/1 - 1s - loss: 1.5948 - mae: 0.3562 - 1s/epoch - 1s/step
# 1/1 - 0s - 140ms/epoch - 140ms/step
# 1/1 - 2s - loss: 0.0437 - mae: 0.1557 - 2s/epoch - 2s/step
# 1/1 - 0s - 197ms/epoch - 197ms/step
# 1/1 - 2s - loss: 22.1682 - mae: 1.2314 - 2s/epoch - 2s/step
# 1/1 - 0s - 157ms/epoch - 157ms/step
# 1/1 - 2s - loss: 2.5148 - mae: 0.1624 - 2s/epoch - 2s/step
# 1/1 - 0s - 156ms/epoch - 156ms/step
# 1/1 - 1s - loss: 0.4622 - mae: 0.6568 - 1s/epoch - 1s/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 20.8531 - mae: 0.5005 - 550ms/epoch - 550ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 2.4926 - mae: 0.1733 - 535ms/epoch - 535ms/step
# 1/1 - 0s - 80ms/epoch - 80ms/step
# 1/1 - 1s - loss: 0.8600 - mae: 0.8275 - 1s/epoch - 1s/step
# 1/1 - 0s - 92ms/epoch - 92ms/step
# 1/1 - 2s - loss: 11.1251 - mae: 1.0003 - 2s/epoch - 2s/step
# 1/1 - 0s - 65ms/epoch - 65ms/step
# 1/1 - 1s - loss: 2.0189 - mae: 0.7596 - 972ms/epoch - 972ms/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 2.1804 - mae: 1.2403 - 667ms/epoch - 667ms/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 9.8523 - mae: 0.3127 - 833ms/epoch - 833ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 3.3614 - mae: 1.3549 - 658ms/epoch - 658ms/step
# 1/1 - 0s - 112ms/epoch - 112ms/step
# 1/1 - 1s - loss: 0.5563 - mae: 0.6068 - 877ms/epoch - 877ms/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 22.8140 - mae: 1.4656 - 1s/epoch - 1s/step
# 1/1 - 0s - 62ms/epoch - 62ms/step
# 1/1 - 1s - loss: 3.0731 - mae: 0.7326 - 1s/epoch - 1s/step
# 1/1 - 0s - 67ms/epoch - 67ms/step
# 1/1 - 1s - loss: 0.4479 - mae: 0.6480 - 675ms/epoch - 675ms/step
# 1/1 - 0s - 113ms/epoch - 113ms/step
# 1/1 - 1s - loss: 21.6940 - mae: 0.8620 - 725ms/epoch - 725ms/step
# 1/1 - 0s - 87ms/epoch - 87ms/step
# 1/1 - 1s - loss: 5.0202 - mae: 1.5598 - 650ms/epoch - 650ms/step
# 1/1 - 0s - 117ms/epoch - 117ms/step
# 1/1 - 1s - loss: 0.9067 - mae: 0.7861 - 918ms/epoch - 918ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 10.5150 - mae: 0.8301 - 964ms/epoch - 964ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 2s - loss: 3.9537 - mae: 1.4426 - 2s/epoch - 2s/step
# 1/1 - 0s - 61ms/epoch - 61ms/step
# 1/1 - 1s - loss: 1.6016 - mae: 1.2255 - 850ms/epoch - 850ms/step
# 1/1 - 0s - 115ms/epoch - 115ms/step
# 1/1 - 1s - loss: 10.4824 - mae: 0.6329 - 742ms/epoch - 742ms/step
# 1/1 - 0s - 73ms/epoch - 73ms/step
# 1/1 - 1s - loss: 2.1239 - mae: 0.6821 - 620ms/epoch - 620ms/step
# 1/1 - 0s - 88ms/epoch - 88ms/step
# 1/1 - 1s - loss: 1.1740 - mae: 0.8234 - 1s/epoch - 1s/step
# 1/1 - 0s - 82ms/epoch - 82ms/step
# 1/1 - 1s - loss: 21.0143 - mae: 0.6415 - 1s/epoch - 1s/step
# 1/1 - 0s - 128ms/epoch - 128ms/step
# 1/1 - 1s - loss: 3.9444 - mae: 0.9709 - 1s/epoch - 1s/step
# 1/1 - 0s - 78ms/epoch - 78ms/step
# 1/1 - 1s - loss: 3.7457 - mae: 1.7927 - 759ms/epoch - 759ms/step
# 1/1 - 0s - 76ms/epoch - 76ms/step
# 1/1 - 1s - loss: 21.8237 - mae: 0.9288 - 811ms/epoch - 811ms/step
# 1/1 - 0s - 81ms/epoch - 81ms/step
# 1/1 - 1s - loss: 2.7305 - mae: 0.4492 - 997ms/epoch - 997ms/step
# 1/1 - 0s - 90ms/epoch - 90ms/step
# 1/1 - 1s - loss: 1.7629 - mae: 0.5415 - 663ms/epoch - 663ms/step
# 9it [19:17, 128.65s/it]

# %%
#Get the best hyperparamters on average by validation scores across all rolling windows (e.g., all validation sets)
mean_val_scores = {params: np.mean(scores) for params,scores in val_scores_dict.items()}
best_params = min(mean_val_scores, key=mean_val_scores.get)
optimised_params = dict(best_params)
print(f'Optimised hyperparameters: {optimised_params} & Average validation score: {mean_val_scores[best_params]}')
# Out:
# Optimised hyperparameters: {'model__activation_func': 'relu', 'model__dropout_rate': 0.0, 'model__learning_rate': 0.001, 'model__neurons_n': (64, 32, 16), 'model__optimizer': 'sgd', 'model__regularize_terms': <keras.src.regularizers.L2 object at 0x0000013D4E8B1070>} & Average validation score: -1.740365930766274

# %%
#Train models with optimised hyperparameters

NN_3 = neural_net_3(input_shape=(X_train.shape[1],),
                    optimizer=optimised_params['model__optimizer'],
                    learning_rate=optimised_params['model__learning_rate'],
                    activation_func=optimised_params['model__activation_func'],
                    dropout_rate=optimised_params['model__dropout_rate'],
                    neurons_n=optimised_params['model__neurons_n'],
                    regularize_terms=optimised_params['model__regularize_terms'])
# Out:
# Epoch 1/10
# 1/1 - 1s - loss: 1.5440 - mae: 0.2218 - val_loss: 1.7271 - val_mae: 0.3760 - 1s/epoch - 1s/step
# Epoch 2/10
# 1/1 - 0s - loss: 1.5410 - mae: 0.2193 - val_loss: 1.7271 - val_mae: 0.3760 - 37ms/epoch - 37ms/step
# Epoch 3/10
# 1/1 - 0s - loss: 1.5382 - mae: 0.2169 - val_loss: 1.7272 - val_mae: 0.3761 - 38ms/epoch - 38ms/step
# Epoch 4/10
# 1/1 - 0s - loss: 1.5355 - mae: 0.2145 - val_loss: 1.7272 - val_mae: 0.3761 - 36ms/epoch - 36ms/step
# Epoch 5/10
# 1/1 - 0s - loss: 1.5330 - mae: 0.2122 - val_loss: 1.7273 - val_mae: 0.3760 - 41ms/epoch - 41ms/step
# Epoch 6/10
# 1/1 - 0s - loss: 1.5305 - mae: 0.2100 - val_loss: 1.7274 - val_mae: 0.3760 - 46ms/epoch - 46ms/step
# Epoch 7/10
# 1/1 - 0s - loss: 1.5283 - mae: 0.2079 - val_loss: 1.7274 - val_mae: 0.3759 - 62ms/epoch - 62ms/step
# Epoch 8/10
# 1/1 - 0s - loss: 1.5261 - mae: 0.2058 - val_loss: 1.7275 - val_mae: 0.3758 - 61ms/epoch - 61ms/step
# Epoch 9/10
# 1/1 - 0s - loss: 1.5240 - mae: 0.2038 - val_loss: 1.7275 - val_mae: 0.3757 - 65ms/epoch - 65ms/step
# Epoch 10/10
# 1/1 - 0s - loss: 1.5219 - mae: 0.2018 - val_loss: 1.7276 - val_mae: 0.3756 - 69ms/epoch - 69ms/step
# 1/1 [==============================] - 0s 117ms/step
# MSE on test set: 35.33485794067383
# MAE on test set: 2.696604013442993

# %%
# make 20 years of training data
date = original_data['date']
training = (date <= '2006-01') # selects 
X_train, y_train = X_NN.loc[training].values, y_NN.loc[training].values 

# make 10 years of validation data
validation = (date > '2002-01') & (date <= '2006-01') 
X_val, y_val = X_NN.loc[validation].values, y_NN.loc[validation].values 

# make test data
test = (date > '2006-01') 
X_test, y_test = X_NN.loc[test].values, y_NN.loc[test].values 

NN3_history = NN_3.fit(X_train, y_train, epochs=100, batch_size=10000, validation_data = (X_val, y_val), verbose=0,  callbacks = [EarlyStopping(patience = 2, restore_best_weights=True)])
predictions = NN_3.predict(X_test)
# Out:
# 24285/24285 [==============================] - 86s 4ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 18
#      16 NN3_history = NN_3.fit(X_train, y_train, epochs=100, batch_size=10000, validation_data = (X_val, y_val), verbose=0,  callbacks = [EarlyStopping(patience = 2, restore_best_weights=True)])
#      17 predictions = NN_3.predict(X_test)
# ---> 18 score = NN_3.evaluate(X_test, y_test, verbose=0)
#      19 numerator=np.sum((y_test - predictions) ** 2)
#      20 denominator=np.sum(y_test ** 2)
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\keras\src\engine\training.py:2200, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2196             with tf.profiler.experimental.Trace(
#    2197                 "test", step_num=step, _r=1
#    2198             ):
#    2199                 callbacks.on_test_batch_begin(step)
# -> 2200                 logs = test_function_runner.run_step(
#    2201                     dataset_or_iterator,
#    2202                     data_handler,
#    2203                     step,
#    2204                     self._pss_evaluation_shards,
#    2205                 )
#    2207 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    2208 # Override with model metrics instead of last step logs
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\keras\src\engine\training.py:4000, in _TestFunction.run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    3999 def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4000     tmp_logs = self._function(dataset_or_iterator)
#    4001     if data_handler.should_sync:
#    4002         context.async_wait()
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:864, in Function._call(self, *args, **kwds)
#     861 self._lock.release()
#     862 # In this case we have not created variables on the first call. So we can
#     863 # run the first trace but we should fail if variables are created.
# --> 864 results = self._variable_creation_fn(*args, **kwds)
#     865 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     866   raise ValueError("Creating variables on a non-first call to a function"
#     867                    " decorated with tf.function.")
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File d:\anaconda3\envs\env_py38\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import mean_squared_error, r2_score
ss_res = np.sum((y_test - predictions.T) ** 2)
ss_tot = np.sum((y_test) ** 2)
r2_out_of_sample = 1 - (ss_res / ss_tot)

# %%
print(r2_out_of_sample)
# Out:
# 0.0010841183019766332

# %%
r2_oos_3 = []

for train_mask, val_mask, test_mask in tqdm(expanding_indices):
    X_train, y_train = X_NN.loc[train_mask].values, y_NN.loc[train_mask].values
    X_val, y_val = X_NN.loc[val_mask].values, y_NN.loc[val_mask].values
    X_test, y_test = X_NN.loc[test_mask].values, y_NN.loc[test_mask].values
    
    NN3_history = NN_3.fit(X_train, y_train, epochs=100, batch_size=10000,
                           validation_data=(X_val, y_val), verbose=0,
                           callbacks=[EarlyStopping(patience=2, restore_best_weights=True)])
    
    predictions = NN_3.predict(X_test)
    ss_res = np.sum((y_test - predictions.T) ** 2)
    ss_tot = np.sum((y_test) ** 2)
    r2_out_of_sample = 1 - (ss_res / ss_tot)
    r2_oos_3.append(r2_out_of_sample)

r2_oos_3_mean = np.mean(r2_oos_3)
print(r2_oos_3_mean)

# %% [markdown]
# **Neural Network model with 4 hidden layers**

# %%
simple_param_grid_nn_4 = {
    'model__optimizer': ['sgd', 'adam', 'rmsprop', 'adagrad'],
    'model__learning_rate': [0.1, 0.01, 0.001, 0.0001],
    'model__activation_func': ['relu', 'tanh', 'sigmoid', 'elu'],
    'model__neurons_n': [[256, 128, 64, 32], [128, 64, 32, 16], [512, 256, 128, 64]],
    'model__dropout_rate': [0.0, 0.2, 0.5],
    'model__regularize_terms': [None, l1(0.1), l1(0.01), l1(0.001), l2(0.1), l2(0.01), l2(0.001), l1_l2(l1=0.1, l2=0.1), l1_l2(l1=0.01, l2=0.01), l1_l2(l1=0.001, l2=0.001)]
}

# %%
def neural_net_4(input_shape, optimizer, learning_rate, activation_func, neurons_n, dropout_rate, regularize_terms, loss_func='mse', metrics_func=['mae']):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Dense(neurons_n[0], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_n[1], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_n[2], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(neurons_n[3], activation=activation_func, kernel_regularizer=regularize_terms))
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    model.add(Dense(1))
    optimizer_instance = tf.keras.optimizers.get(optimizer)
    optimizer_instance.learning_rate = learning_rate
    model.compile(optimizer=optimizer_instance, loss=loss_func, metrics=metrics_func)
    return model

# %%
val_scores_dict_4 = defaultdict(list)

for train_indices, test_indices in tqdm(rolling_window_index_generator(X_train=X_train, step_size=n_train_window), file=sys.stdout):
    X_train_cv, y_train_cv = X_train[train_indices], y_train[train_indices]
    X_val_cv, y_val_cv = X_train[test_indices], y_train[test_indices]

    current_fold = np.zeros(X_train_cv.shape[0] + X_val_cv.shape[0])
    current_fold[:X_train_cv.shape[0]] = -1
    current_fold[X_train_cv.shape[0]:] = 0
    ps = skl.model_selection.PredefinedSplit(current_fold)

    X_combined = np.vstack((X_train_cv, X_val_cv))
    y_combined = np.concatenate((y_train_cv, y_val_cv))

    NN_4 = KerasRegressor(model=neural_net_4, input_shape=(X_combined.shape[1],), verbose=2)
    grid_2 = skl.model_selection.GridSearchCV(estimator=NN_4, param_grid=simple_param_grid_nn_4, scoring='neg_mean_squared_error', cv=ps, error_score='raise')
    grid_2.fit(X_combined, y_combined)

    for params, mean_score in zip(grid_2.cv_results_['params'], grid_2.cv_results_['mean_test_score']):
        hashable_params = make_hashable(params)
        val_scores_dict_4[tuple(hashable_params.items())].append(mean_score)

mean_val_scores_4 = {params: np.mean(scores) for params, scores in val_scores_dict_4.items()}
best_params_4 = min(mean_val_scores_4, key=mean_val_scores_4.get)
optimised_params_4 = dict(best_params_4)
print(f'Optimised hyperparameters for 2 layers: {optimised_params_4} & Average validation score: {mean_val_scores_4[best_params_4]}')

# %%
NN_4 = neural_net_4(input_shape=(X_train.shape[1],),
                    optimizer=optimised_params_4['model__optimizer'],
                    learning_rate=optimised_params_4['model__learning_rate'],
                    activation_func=optimised_params_4['model__activation_func'],
                    dropout_rate=optimised_params_4['model__dropout_rate'],
                    neurons_n=optimised_params_4['model__neurons_n'],
                    regularize_terms=optimised_params_4['model__regularize_terms'])

# %%
r2_oos_4 = []

for train_mask, val_mask, test_mask in tqdm(expanding_indices):
    X_train, y_train = X_NN.loc[train_mask].values, y_NN.loc[train_mask].values
    X_val, y_val = X_NN.loc[val_mask].values, y_NN.loc[val_mask].values
    X_test, y_test = X_NN.loc[test_mask].values, y_NN.loc[test_mask].values
    
    NN4_history = NN_4.fit(X_train, y_train, epochs=100, batch_size=10000,
                           validation_data=(X_val, y_val), verbose=0,
                           callbacks=[EarlyStopping(patience=2, restore_best_weights=True)])
    
    predictions = NN_4.predict(X_test)
    ss_res = np.sum((y_test - predictions.T) ** 2)
    ss_tot = np.sum((y_test) ** 2)
    r2_out_of_sample = 1 - (ss_res / ss_tot)
    r2_oos_4.append(r2_out_of_sample)

r2_oos_4_mean = np.mean(r2_oos_4)
print(r2_oos_4_mean)
